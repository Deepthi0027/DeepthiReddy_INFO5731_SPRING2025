# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Monday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**
#
# **Please check that the link you submitted can be opened and points to the correct assignment.**

# %% [markdown]
# # Question 1 (25 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
#
# (3) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (4) Collect all the information of the 904 narrators in the Densho Digital Repository.
#
# (5)**Collect a total of 10000 reviews** of the top 100 most popular software from G2 and Capterra.

# %%
# Your code here
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_imdb_reviews(no_of_reviews=1000):
    base_url = 'https://www.imdb.com/title/tt5296406/reviews'
    reviews = []
    page_num = 0  # Adjust pagination based on IMDb's structure

    while len(reviews) < no_of_reviews:
        url = f'{base_url}?start={page_num}'
        response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract review text using the identified class
        review_containers = soup.find_all('div', class_='ipc-html-content ipc-html-content--base')
        for container in review_containers:
            inner_div = container.find('div', class_='ipc-html-content-inner-div')
            if inner_div:
                reviews.append(inner_div.text.strip())

        page_num += 1  # Increment by 1 for pagination

    return reviews[:no_of_reviews]

# Scraping top 1000 user reviews
designated_survivor_reviews = scrape_imdb_reviews(1000)
print(designated_survivor_reviews[:5])
print(len(designated_survivor_reviews))
# Out:
# ["I enjoyed the first two seasons of Designated Survivor it was entertaining and kept your interest. If your a 24 fan you will enjoy the first two seasons it's basically if Jack Bauer became president. The third season it fell apart with the removal of some of the cast with no explanation. They also added lots of unnecessary cussing that did not fit the vibe it totally changed the mood of the show.", 'Season One and Two were fantastic: Interesting, gripping, great cast and production. I couldn\'t wait for the next episode. After Netflix took over Season Three, I stopped watching after about one-third of the episodes. Season Three is obsessed and strategized with misguided identity politics, "politically correct" content, and crass language. The screenplays for Season Three are amateurish and nowhere match those of Season One and Two. Strange, when Netflix produces, things get sleazy.', 'I really liked "Designated Survivor" for the first two seasons (gave them a rating of 9) and was happy when they announced that Netfkix was going to do a thrid season, but not only is this season dull (do they have new script writers?) but they have added crude language and graphic sex which is disappointing. The story line of Kirkman running for president is done in a lousy way. The new characters are obnoxious straight down the line even though the actors who play them are, for the most part, decent actors. Overacted and with the feeling that everyone except Sutherland are just phoning it in. This is turning me off pretty quickly. How could Netflix ruin what was a decent series? Those of us who were watching it most likely didn\'t watch a lot of "House of Cards" and that is not what we want.', "I've liked this show even though it's a little liberal for me. I was excited Netflix picked it up after being cancelled. Why did Netflix have to add the cursing? The show was fine without it. Language doesn't add anything to the quality of the show. I know everyone thinks it makes it more realistic but I disagree. It just isn't needed.", "This show is one of my favourite Netflix Originals. It kind of combines House of Cards (2013) with 24 (2001) really well with it being half political drama and half action thriller. All of the main cast play such amazing, likeable but flawed characters. Season One is by far the best because you just had no idea where it was going, season two kept the suspense with a different story every week but still had long running stories. Season three however wasn't that good. It had some good moments but it just felt like a very different show."]
# 1000

# %%
reviews_df = pd.DataFrame(designated_survivor_reviews, columns=['reviews'])
reviews_df.head()
# Out:
#                                              reviews
# 0  I enjoyed the first two seasons of Designated ...
# 1  Season One and Two were fantastic: Interesting...
# 2  I really liked "Designated Survivor" for the f...
# 3  I've liked this show even though it's a little...
# 4  This show is one of my favourite Netflix Origi...

# %%
reviews_df.to_csv('Designated_reviews.csv', index=False)
print(' Reviews are collected, and saved successfully ')
# Out:
#  Reviews are collected, and saved successfully

# %% [markdown]
# # Question 2 (15 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.
#importing all the required modules
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import string
import re

# Download NLTK resources
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
data = "/content/Designated_reviews.csv"
df = pd.read_table(data,names=['text'])
df.head()
# Out:
#                                                 text
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic: Interesting...
# 3  I really liked "Designated Survivor" for the f...
# 4  I've liked this show even though it's a little...

# %%
#1:Remove noise, such as special characters and punctuations.
def remove_noise(text):
    clean_text = re.sub('[^a-zA-Z0-9]', ' ', text)
    return clean_text
df['clean_text'] = df['text'].apply(remove_noise)
# Displaying the Data Frame after removing noise
print("\nData Frame after removing noise:")
df.head(10)
# Out:
# Data Frame after removing noise:
#                                                 text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic: Interesting...
# 3  I really liked "Designated Survivor" for the f...
# 4  I've liked this show even though it's a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant, season one is fantastic...
# 7  This show, which I stumbled upon when trying t...
# 8  I've just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president! ...
#
#                                           clean_text
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...

# %%
#2: Remove Numbers
def remove_numbers(text):
    clean_text = re.sub(r'\d+', '', text)
    return clean_text
df['remove_numbers'] = df['clean_text'].apply(remove_numbers)
print("\nData Frame after removing numbers:")
df.head(10)
# Out:
# Data Frame after removing numbers:
#                                                 text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic: Interesting...
# 3  I really liked "Designated Survivor" for the f...
# 4  I've liked this show even though it's a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant, season one is fantastic...
# 7  This show, which I stumbled upon when trying t...
# 8  I've just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president! ...
#
#                                           clean_text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...
#
#                                       remove_numbers
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...

# %%
# 3: Remove stopwords by using the stopwords List
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = nltk.word_tokenize(text)
    filter_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filter_words)
df['remove_stopwords'] = df['remove_numbers'].apply(remove_stopwords)
print("\nData Frame after removing stopwords without lowercase:")
df.head(10)
# Out:
# Data Frame after removing stopwords without lowercase:
#                                                 text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic: Interesting...
# 3  I really liked "Designated Survivor" for the f...
# 4  I've liked this show even though it's a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant, season one is fantastic...
# 7  This show, which I stumbled upon when trying t...
# 8  I've just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president! ...
#
#                                           clean_text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...
#
#                                       remove_numbers  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...
#
#                                     remove_stopwords
# 0                                            reviews
# 1  enjoyed first two seasons Designated Survivor ...
# 2  Season One Two fantastic Interesting gripping ...
# 3  really liked Designated Survivor first two sea...
# 4  liked show even though little liberal excited ...
# 5  show one favourite Netflix Originals kind comb...
# 6  Started brilliant season one fantastic Season ...
# 7  show stumbled upon trying find something watch...
# 8  binge watched end Episode initial premise inte...
# 9  wish Tom Kirkman actual president Great charac...

# %%
# 4: Lowercase all texts
df['lowercase_texts'] = df['remove_stopwords'].apply(lambda x: x.lower())
print("\nData Frame after converting texts to lowercase:")
df.head(10)
# Out:
# Data Frame after converting texts to lowercase:
#                                                 text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic: Interesting...
# 3  I really liked "Designated Survivor" for the f...
# 4  I've liked this show even though it's a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant, season one is fantastic...
# 7  This show, which I stumbled upon when trying t...
# 8  I've just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president! ...
#
#                                           clean_text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...
#
#                                       remove_numbers  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...
#
#                                     remove_stopwords  \
# 0                                            reviews
# 1  enjoyed first two seasons Designated Survivor ...
# 2  Season One Two fantastic Interesting gripping ...
# 3  really liked Designated Survivor first two sea...
# 4  liked show even though little liberal excited ...
# 5  show one favourite Netflix Originals kind comb...
# 6  Started brilliant season one fantastic Season ...
# 7  show stumbled upon trying find something watch...
# 8  binge watched end Episode initial premise inte...
# 9  wish Tom Kirkman actual president Great charac...
#
#                                      lowercase_texts
# 0                                            reviews
# 1  enjoyed first two seasons designated survivor ...
# 2  season one two fantastic interesting gripping ...
# 3  really liked designated survivor first two sea...
# 4  liked show even though little liberal excited ...
# 5  show one favourite netflix originals kind comb...
# 6  started brilliant season one fantastic season ...
# 7  show stumbled upon trying find something watch...
# 8  binge watched end episode initial premise inte...
# 9  wish tom kirkman actual president great charac...

# %%
#5. Stemming
stemmer = PorterStemmer()
def apply_stemming(text):
    words = nltk.word_tokenize(text)
    stemmed_words = [stemmer.stem(word) for word in words]
    return ' '.join(stemmed_words)
df['after_stemming'] = df['lowercase_texts'].apply(apply_stemming)
print("\nData Frame after applying stemming:")
df.head(10)
# Out:
# Data Frame after applying stemming:
#                                                 text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic: Interesting...
# 3  I really liked "Designated Survivor" for the f...
# 4  I've liked this show even though it's a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant, season one is fantastic...
# 7  This show, which I stumbled upon when trying t...
# 8  I've just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president! ...
#
#                                           clean_text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...
#
#                                       remove_numbers  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...
#
#                                     remove_stopwords  \
# 0                                            reviews
# 1  enjoyed first two seasons Designated Survivor ...
# 2  Season One Two fantastic Interesting gripping ...
# 3  really liked Designated Survivor first two sea...
# 4  liked show even though little liberal excited ...
# 5  show one favourite Netflix Originals kind comb...
# 6  Started brilliant season one fantastic Season ...
# 7  show stumbled upon trying find something watch...
# 8  binge watched end Episode initial premise inte...
# 9  wish Tom Kirkman actual president Great charac...
#
#                                      lowercase_texts  \
# 0                                            reviews
# 1  enjoyed first two seasons designated survivor ...
# 2  season one two fantastic interesting gripping ...
# 3  really liked designated survivor first two sea...
# 4  liked show even though little liberal excited ...
# 5  show one favourite netflix originals kind comb...
# 6  started brilliant season one fantastic season ...
# 7  show stumbled upon trying find something watch...
# 8  binge watched end episode initial premise inte...
# 9  wish tom kirkman actual president great charac...
#
#                                       after_stemming
# 0                                             review
# 1  enjoy first two season design survivor enterta...
# 2  season one two fantast interest grip great cas...
# 3  realli like design survivor first two season g...
# 4  like show even though littl liber excit netfli...
# 5  show one favourit netflix origin kind combin h...
# 6  start brilliant season one fantast season good...
# 7  show stumbl upon tri find someth watch grab ri...
# 8  bing watch end episod initi premis interest wh...
# 9  wish tom kirkman actual presid great charact k...

# %%
#6. Lemmatization
lemmatizer = WordNetLemmatizer()
def apply_lemmatization(text):
    words = nltk.word_tokenize(text)
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)
df['after_lemmatization'] = df['after_stemming'].apply(apply_lemmatization)
print("\nData Frame after applying lemmatization:")
df.head(10)
# Out:
# Data Frame after applying lemmatization:
#                                                 text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic: Interesting...
# 3  I really liked "Designated Survivor" for the f...
# 4  I've liked this show even though it's a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant, season one is fantastic...
# 7  This show, which I stumbled upon when trying t...
# 8  I've just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president! ...
#
#                                           clean_text  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...
#
#                                       remove_numbers  \
# 0                                            reviews
# 1  I enjoyed the first two seasons of Designated ...
# 2  Season One and Two were fantastic  Interesting...
# 3  I really liked  Designated Survivor  for the f...
# 4  I ve liked this show even though it s a little...
# 5  This show is one of my favourite Netflix Origi...
# 6  Started off brilliant  season one is fantastic...
# 7  This show  which I stumbled upon when trying t...
# 8  I ve just binge watched it up to the end of Ep...
# 9  I wish Tom Kirkman were our actual president  ...
#
#                                     remove_stopwords  \
# 0                                            reviews
# 1  enjoyed first two seasons Designated Survivor ...
# 2  Season One Two fantastic Interesting gripping ...
# 3  really liked Designated Survivor first two sea...
# 4  liked show even though little liberal excited ...
# 5  show one favourite Netflix Originals kind comb...
# 6  Started brilliant season one fantastic Season ...
# 7  show stumbled upon trying find something watch...
# 8  binge watched end Episode initial premise inte...
# 9  wish Tom Kirkman actual president Great charac...
#
#                                      lowercase_texts  \
# 0                                            reviews
# 1  enjoyed first two seasons designated survivor ...
# 2  season one two fantastic interesting gripping ...
# 3  really liked designated survivor first two sea...
# 4  liked show even though little liberal excited ...
# 5  show one favourite netflix originals kind comb...
# 6  started brilliant season one fantastic season ...
# 7  show stumbled upon trying find something watch...
# 8  binge watched end episode initial premise inte...
# 9  wish tom kirkman actual president great charac...
#
#                                       after_stemming  \
# 0                                             review
# 1  enjoy first two season design survivor enterta...
# 2  season one two fantast interest grip great cas...
# 3  realli like design survivor first two season g...
# 4  like show even though littl liber excit netfli...
# 5  show one favourit netflix origin kind combin h...
# 6  start brilliant season one fantast season good...
# 7  show stumbl upon tri find someth watch grab ri...
# 8  bing watch end episod initi premis interest wh...
# 9  wish tom kirkman actual presid great charact k...
#
#                                  after_lemmatization
# 0                                             review
# 1  enjoy first two season design survivor enterta...
# 2  season one two fantast interest grip great cas...
# 3  realli like design survivor first two season g...
# 4  like show even though littl liber excit netfli...
# 5  show one favourit netflix origin kind combin h...
# 6  start brilliant season one fantast season good...
# 7  show stumbl upon tri find someth watch grab ri...
# 8  bing watch end episod initi premis interest wh...
# 9  wish tom kirkman actual presid great charact k...

# %%
# Save the cleaned data to a new CSV file
df.to_csv('cleaned_data_.csv', index=False)
print("\nCleaned data saved ")
# Out:
# Cleaned data saved

# %% [markdown]
# # Question 3 (15 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Your code here
# Part 1: Parts of Speech (POS) Tagging
from collections import Counter
nltk.download('averaged_perceptron_tagger_eng')

# Read the data from cleaned_data_.csv
df = pd.read_csv('cleaned_data_.csv')

def pos_tagging(text):
    tokens = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    return pos_tags
# Iterate through each row and print the POS tagging on a new line
for index, row in df.iterrows():
    pos_tags = pos_tagging(row['clean_text'])
    print(f"POS tagging for row {index + 1}:\n{pos_tags}\n")
    noun_count = verb_count = adj_count = adv_count = 0
    for _, pos in pos_tags:
        if pos.startswith('N'):
            noun_count += 1
        elif pos.startswith('V'):
            verb_count += 1
        elif pos.startswith('JJ'):
            adj_count += 1
        elif pos.startswith('RB'):
            adv_count += 1
    print(f"Total No of Nouns: {noun_count}")
    print(f"Total No of Verbs: {verb_count}")
    print(f"Total No of Adjectives: {adj_count}")
    print(f"Total No of Adverbs: {adv_count}")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# Streaming output truncated to the last 5000 lines.
# Total No of Adjectives: 5
# Total No of Adverbs: 3
# POS tagging for row 288:
# [('The', 'DT'), ('pilot', 'NN'), ('episode', 'NN'), ('was', 'VBD'), ('intriguing', 'VBG'), ('but', 'CC'), ('as', 'IN'), ('Designated', 'NNP'), ('Survivor', 'NNP'), ('just', 'RB'), ('watched', 'VBD'), ('episode', 'RB'), ('5', 'CD'), ('goes', 'VBZ'), ('on', 'IN'), ('it', 'PRP'), ('s', 'VBZ'), ('really', 'RB'), ('hitting', 'VBG'), ('it', 'PRP'), ('s', 'JJ'), ('stride', 'JJ'), ('Kiefer', 'NNP'), ('s', 'NN'), ('acting', 'NN'), ('is', 'VBZ'), ('compelling', 'VBG'), ('and', 'CC'), ('all', 'DT'), ('of', 'IN'), ('the', 'DT'), ('characters', 'NNS'), ('are', 'VBP'), ('beginning', 'VBG'), ('to', 'TO'), ('get', 'VB'), ('fleshed', 'VBN'), ('out', 'RP'), ('as', 'IN'), ('the', 'DT'), ('story', 'NN'), ('begins', 'VBZ'), ('to', 'TO'), ('come', 'VB'), ('together', 'RB'), ('The', 'DT'), ('idea', 'NN'), ('of', 'IN'), ('an', 'DT'), ('every', 'DT'), ('man', 'NN'), ('becoming', 'VBG'), ('President', 'NNP'), ('is', 'VBZ'), ('interesting', 'JJ'), ('as', 'IN'), ('he', 'PRP'), ('copes', 'VBZ'), ('with', 'IN'), ('the', 'DT'), ('difficult', 'JJ'), ('choices', 'NNS'), ('he', 'PRP'), ('has', 'VBZ'), ('to', 'TO'), ('make', 'VB'), ('and', 'CC'), ('the', 'DT'), ('effects', 'NNS'), ('his', 'PRP$'), ('new', 'JJ'), ('job', 'NN'), ('have', 'VBP'), ('on', 'IN'), ('him', 'PRP'), ('and', 'CC'), ('his', 'PRP$'), ('family', 'NN'), ('Actually', 'RB'), ('showing', 'VBG'), ('the', 'DT'), ('incredible', 'JJ'), ('toll', 'NN'), ('that', 'IN'), ('making', 'VBG'), ('life', 'NN'), ('and', 'CC'), ('death', 'NN'), ('decisions', 'NNS'), ('a', 'DT'), ('decent', 'JJ'), ('man', 'NN'), ('who', 'WP'), ('is', 'VBZ'), ('president', 'NN'), ('has', 'VBZ'), ('to', 'TO'), ('make', 'VB'), ('is', 'VBZ'), ('so', 'RB'), ('enlightening', 'JJ'), ('and', 'CC'), ('Kiefer', 'NNP'), ('is', 'VBZ'), ('masterful', 'JJ'), ('at', 'IN'), ('portraying', 'VBG'), ('the', 'DT'), ('pathos', 'NN'), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('the', 'DT'), ('joy', 'NN'), ('Adding', 'VBG'), ('the', 'DT'), ('conspiracy', 'NN'), ('suspense', 'NN'), ('to', 'TO'), ('the', 'DT'), ('mix', 'NN'), ('makes', 'VBZ'), ('it', 'PRP'), ('edge', 'NN'), ('of', 'IN'), ('your', 'PRP$'), ('seat', 'NN'), ('viewing', 'VBG'), ('This', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('first', 'JJ'), ('new', 'JJ'), ('show', 'NN'), ('in', 'IN'), ('a', 'DT'), ('long', 'JJ'), ('time', 'NN'), ('that', 'IN'), ('I', 'PRP'), ('actually', 'RB'), ('look', 'VBP'), ('forward', 'RB'), ('to', 'TO'), ('watching', 'VBG')]
#
# Total No of Nouns: 32
# Total No of Verbs: 34
# Total No of Adjectives: 12
# Total No of Adverbs: 10
# POS tagging for row 289:
# [('Season', 'NNP'), ('1', 'CD'), ('and', 'CC'), ('2', 'CD'), ('Designated', 'NNP'), ('Surivor', 'NNP'), ('introduced', 'VBD'), ('plots', 'NNS'), ('and', 'CC'), ('narratives', 'NNS'), ('that', 'WDT'), ('were', 'VBD'), ('a', 'DT'), ('mixed', 'JJ'), ('bag', 'NN'), ('Some', 'DT'), ('were', 'VBD'), ('enthralling', 'VBG'), ('and', 'CC'), ('alluded', 'VBD'), ('to', 'TO'), ('bigger', 'JJR'), ('plots', 'NNS'), ('but', 'CC'), ('ultimately', 'RB'), ('led', 'VBD'), ('to', 'TO'), ('nowhere', 'RB'), ('or', 'CC'), ('went', 'VBD'), ('out', 'RP'), ('with', 'IN'), ('a', 'DT'), ('whimper', 'NN'), ('Other', 'JJ'), ('elements', 'NNS'), ('led', 'VBN'), ('to', 'TO'), ('unforseen', 'JJ'), ('twists', 'NNS'), ('which', 'WDT'), ('spiced', 'VBD'), ('up', 'RP'), ('the', 'DT'), ('story', 'NN'), ('Without', 'IN'), ('any', 'DT'), ('spoilers', 'NNS'), ('there', 'EX'), ('were', 'VBD'), ('plots', 'NNS'), ('that', 'IN'), ('I', 'PRP'), ('had', 'VBD'), ('hoped', 'VBN'), ('were', 'VBD'), ('expanded', 'VBN'), ('upon', 'NN'), ('or', 'CC'), ('developed', 'VB'), ('further', 'JJR'), ('rather', 'RB'), ('than', 'IN'), ('being', 'VBG'), ('conviniently', 'RB'), ('wrapped', 'VBN'), ('up', 'RP'), ('by', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('the', 'DT'), ('episode', 'NN'), ('with', 'IN'), ('little', 'JJ'), ('consequence', 'NN'), ('However', 'RB'), ('with', 'IN'), ('that', 'DT'), ('being', 'VBG'), ('said', 'VBD'), ('there', 'EX'), ('were', 'VBD'), ('little', 'JJ'), ('details', 'NNS'), ('that', 'WDT'), ('turned', 'VBD'), ('into', 'IN'), ('something', 'NN'), ('big', 'JJ'), ('and', 'CC'), ('added', 'VBD'), ('a', 'DT'), ('bit', 'NN'), ('of', 'IN'), ('danger', 'NN'), ('to', 'TO'), ('the', 'DT'), ('story', 'NN'), ('Maybe', 'RB'), ('this', 'DT'), ('was', 'VBD'), ('due', 'JJ'), ('to', 'TO'), ('budget', 'NN'), ('constraints', 'NNS'), ('or', 'CC'), ('ABC', 'NNP'), ('oversight', 'MD'), ('from', 'IN'), ('preventing', 'VBG'), ('the', 'DT'), ('series', 'NN'), ('from', 'IN'), ('becoming', 'VBG'), ('too', 'RB'), ('dark', 'JJ'), ('because', 'IN'), ('I', 'PRP'), ('don', 'VBP'), ('t', 'JJ'), ('believe', 'VBP'), ('that', 'IN'), ('the', 'DT'), ('writers', 'NNS'), ('who', 'WP'), ('brainstormed', 'VBD'), ('some', 'DT'), ('pretty', 'RB'), ('solid', 'JJ'), ('ideas', 'NNS'), ('wanted', 'VBD'), ('those', 'DT'), ('ideas', 'NNS'), ('to', 'TO'), ('pan', 'VB'), ('out', 'RP'), ('the', 'DT'), ('way', 'NN'), ('they', 'PRP'), ('did', 'VBD'), ('Season', 'NNP'), ('3', 'CD'), ('is', 'VBZ'), ('helmed', 'VBN'), ('purely', 'RB'), ('by', 'IN'), ('Netflix', 'NNP'), ('and', 'CC'), ('it', 'PRP'), ('shows', 'VBZ'), ('That', 'IN'), ('s', 'NN'), ('not', 'RB'), ('necessarily', 'RB'), ('a', 'DT'), ('good', 'JJ'), ('nor', 'CC'), ('bad', 'JJ'), ('thing', 'NN'), ('The', 'DT'), ('season', 'NN'), ('still', 'RB'), ('suffers', 'VBZ'), ('from', 'IN'), ('the', 'DT'), ('long', 'JJ'), ('build', 'NN'), ('and', 'CC'), ('anti', 'JJ'), ('climatic', 'JJ'), ('whimper', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('two', 'CD'), ('seasons', 'NNS'), ('had', 'VBD'), ('Some', 'DT'), ('story', 'NN'), ('points', 'NNS'), ('just', 'RB'), ('wrapped', 'VBD'), ('up', 'RP'), ('too', 'RB'), ('quickly', 'RB'), ('after', 'IN'), ('they', 'PRP'), ('build', 'VBP'), ('up', 'RP'), ('they', 'PRP'), ('were', 'VBD'), ('given', 'VBN'), ('In', 'IN'), ('essence', 'NN'), ('great', 'JJ'), ('concepts', 'NNS'), ('but', 'CC'), ('poor', 'JJ'), ('execution', 'NN'), ('still', 'RB'), ('plagues', 'VBZ'), ('this', 'DT'), ('series', 'NN'), ('The', 'DT'), ('language', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('bit', 'NN'), ('vulgar', 'JJ'), ('and', 'CC'), ('gratuitous', 'JJ'), ('hitting', 'VBG'), ('me', 'PRP'), ('like', 'IN'), ('a', 'DT'), ('freight', 'NN'), ('train', 'NN'), ('roaring', 'VBG'), ('down', 'RP'), ('a', 'DT'), ('mountain', 'NN'), ('The', 'DT'), ('showed', 'VBN'), ('laid', 'IN'), ('it', 'PRP'), ('on', 'IN'), ('heavy', 'NN'), ('probably', 'RB'), ('wanting', 'VBG'), ('to', 'TO'), ('hammer', 'VB'), ('home', 'NN'), ('that', 'WDT'), ('Designated', 'NNP'), ('Survivor', 'NN ...
#
# Total No of Nouns: 213
# Total No of Verbs: 181
# Total No of Adjectives: 96
# Total No of Adverbs: 73
# POS tagging for row 290:
# [('This', 'DT'), ('show', 'NN'), ('started', 'VBD'), ('off', 'RP'), ('REALLY', 'NNP'), ('well', 'RB'), ('I', 'PRP'), ('was', 'VBD'), ('right', 'RB'), ('into', 'IN'), ('after', 'IN'), ('Season', 'NNP'), ('1', 'CD'), ('Season', 'NNP'), ('2', 'CD'), ('fell', 'VBD'), ('apart', 'RB'), ('after', 'IN'), ('awhile', 'NN'), ('I', 'PRP'), ('realized', 'VBD'), ('that', 'IN'), ('if', 'IN'), ('I', 'PRP'), ('wasn', 'VBP'), ('t', 'JJ'), ('watching', 'VBG'), ('episodes', 'NNS'), ('back', 'RB'), ('to', 'TO'), ('back', 'VB'), ('there', 'EX'), ('would', 'MD'), ('be', 'VB'), ('at', 'IN'), ('least', 'JJS'), ('a', 'DT'), ('week', 'NN'), ('in', 'IN'), ('between', 'IN'), ('shows', 'NNS'), ('so', 'IN'), ('the', 'DT'), ('randomness', 'NN'), ('might', 'MD'), ('not', 'RB'), ('be', 'VB'), ('as', 'IN'), ('blatant', 'JJ'), ('like', 'IN'), ('characters', 'NNS'), ('just', 'RB'), ('vanishing', 'VBG'), ('off', 'RP'), ('the', 'DT'), ('show', 'NN'), ('with', 'IN'), ('sometimes', 'RB'), ('not', 'RB'), ('even', 'RB'), ('a', 'DT'), ('mention', 'NN'), ('The', 'DT'), ('formula', 'NN'), ('of', 'IN'), ('crisis', 'NN'), ('is', 'VBZ'), ('introduced', 'VBN'), ('crisis', 'NN'), ('is', 'VBZ'), ('explained', 'VBN'), ('as', 'IN'), ('how', 'WRB'), ('it', 'PRP'), ('will', 'MD'), ('hurt', 'VB'), ('the', 'DT'), ('presidents', 'NNS'), ('reputation', 'NN'), ('crisis', 'NN'), ('is', 'VBZ'), ('averted', 'VBN'), ('with', 'IN'), ('some', 'DT'), ('kind', 'NN'), ('of', 'IN'), ('personal', 'JJ'), ('sacrifice', 'NN'), ('from', 'IN'), ('the', 'DT'), ('president', 'NN'), ('Rinse', 'NNP'), ('and', 'CC'), ('repeat', 'NN'), ('after', 'IN'), ('every', 'DT'), ('episode', 'NN'), ('I', 'PRP'), ('stopped', 'VBD'), ('about', 'IN'), ('3', 'CD'), ('4', 'CD'), ('of', 'IN'), ('the', 'DT'), ('way', 'NN'), ('through', 'IN'), ('season', 'NN'), ('2', 'CD'), ('I', 'PRP'), ('just', 'RB'), ('can', 'MD'), ('t', 'VB'), ('do', 'VB'), ('it', 'PRP'), ('anymore', 'RB'), ('with', 'IN'), ('this', 'DT'), ('show', 'NN'), ('I', 'PRP'), ('don', 'VBP'), ('t', 'JJ'), ('remember', 'VB'), ('seeing', 'VBG'), ('a', 'DT'), ('show', 'NN'), ('tank', 'NN'), ('as', 'IN'), ('fast', 'RB'), ('as', 'IN'), ('this', 'DT'), ('one', 'CD'), ('Super', 'NNP'), ('disappointing', 'NN'), ('with', 'IN'), ('where', 'WRB'), ('this', 'DT'), ('show', 'NN'), ('went', 'VBD'), ('I', 'PRP'), ('think', 'VBP'), ('if', 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('looking', 'VBG'), ('for', 'IN'), ('a', 'DT'), ('political', 'JJ'), ('drama', 'NN'), ('The', 'DT'), ('West', 'NNP'), ('Wing', 'NNP'), ('would', 'MD'), ('be', 'VB'), ('better', 'JJR')]
#
# Total No of Nouns: 35
# Total No of Verbs: 28
# Total No of Adjectives: 7
# Total No of Adverbs: 12
# POS tagging for row 291:
# [('If', 'IN'), ('you', 'PRP'), ('can', 'MD'), ('get', 'VB'), ('past', 'IN'), ('an', 'DT'), ('enemy', 'NN'), ('being', 'VBG'), ('able', 'JJ'), ('to', 'TO'), ('blow', 'VB'), ('up', 'RP'), ('the', 'DT'), ('Capitol', 'NNP'), ('during', 'IN'), ('the', 'DT'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('leaving', 'VBG'), ('only', 'RB'), ('a', 'DT'), ('single', 'JJ'), ('representative', 'NN'), ('and', 'CC'), ('the', 'DT'), ('Secretary', 'NNP'), ('of', 'IN'), ('HUD', 'NNP'), ('as', 'IN'), ('designated', 'VBN'), ('survivors', 'NNS'), ('then', 'RB'), ('this', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('fantastic', 'JJ'), ('show', 'NN'), ('The', 'DT'), ('challenges', 'NNS'), ('would', 'MD'), ('be', 'VB'), ('almost', 'RB'), ('insurmountable', 'JJ'), ('and', 'CC'), ('Kiefer', 'NNP'), ('Sutherland', 'NNP'), ('is', 'VBZ'), ('awesome', 'JJ'), ('His', 'PRP$'), ('character', 'NN'), ('is', 'VBZ'), ('growing', 'VBG'), ('every', 'DT'), ('week', 'NN'), ('His', 'PRP$'), ('wife', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('strong', 'JJ'), ('woman', 'NN'), ('an', 'DT'), ('attorney', 'NN'), ('and', 'CC'), ('will', 'MD'), ('obviously', 'RB'), ('make', 'VB'), ('a', 'DT'), ('great', 'JJ'), ('First', 'NNP'), ('Lady', 'NNP'), ('His', 'PRP$'), ('oldest', 'JJS'), ('son', 'NN'), ('has', 'VBZ'), ('issues', 'NNS'), ('so', 'IN'), ('it', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('interesting', 'JJ'), ('to', 'TO'), ('see', 'VB'), ('how', 'WRB'), ('that', 'DT'), ('all', 'DT'), ('falls', 'VBZ'), ('out', 'RP'), ('There', 'EX'), ('also', 'RB'), ('seems', 'VBZ'), ('to', 'TO'), ('be', 'VB'), ('some', 'DT'), ('mystery', 'NN'), ('surrounding', 'VBG'), ('one', 'CD'), ('survivor', 'NN'), ('of', 'IN'), ('the', 'DT'), ('bombing', 'NN'), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('the', 'DT'), ('actions', 'NNS'), ('of', 'IN'), ('state', 'NN'), ('governors', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('wake', 'NN'), ('of', 'IN'), ('the', 'DT'), ('disaster', 'NN'), ('To', 'TO'), ('me', 'PRP'), ('this', 'DT'), ('is', 'VBZ'), ('reminiscent', 'JJ'), ('of', 'IN'), ('The', 'DT'), ('West', 'NNP'), ('Wing', 'NNP'), ('at', 'IN'), ('least', 'JJS'), ('so', 'RB'), ('far', 'RB'), ('I', 'PRP'), ('highly', 'RB'), ('recommend', 'VBP'), ('this', 'DT')]
#
# Total No of Nouns: 31
# Total No of Verbs: 21
# Total No of Adjectives: 11
# Total No of Adverbs: 10
# POS tagging for row 292:
# [('It', 'PRP'), ('really', 'RB'), ('is', 'VBZ'), ('an', 'DT'), ('older', 'JJR'), ('Jack', 'NNP'), ('Bauer', 'NNP'), ('as', 'IN'), ('the', 'DT'), ('President', 'NNP'), ('He', 'PRP'), ('doesn', 'VBD'), ('t', 'RB'), ('need', 'VB'), ('a', 'DT'), ('gun', 'NN'), ('anymore', 'RB'), ('but', 'CC'), ('his', 'PRP$'), ('moral', 'JJ'), ('compass', 'NN'), ('is', 'VBZ'), ('just', 'RB'), ('as', 'IN'), ('strong', 'JJ'), ('His', 'PRP$'), ('character', 'NN'), ('is', 'VBZ'), ('learning', 'VBG'), ('what', 'WP'), ('it', 'PRP'), ('means', 'VBZ'), ('to', 'TO'), ('have', 'VB'), ('power', 'NN'), ('and', 'CC'), ('manipulate', 'NN'), ('people', 'NNS'), ('to', 'TO'), ('do', 'VB'), ('what', 'WP'), ('is', 'VBZ'), ('needed', 'VBN'), ('Its', 'PRP$'), ('only', 'RB'), ('been', 'VBN'), ('two', 'CD'), ('days', 'NNS'), ('since', 'IN'), ('the', 'DT'), ('incident', 'NN'), ('so', 'RB'), ('I', 'PRP'), ('guess', 'VBP'), ('its', 'PRP$'), ('to', 'TO'), ('early', 'JJ'), ('to', 'TO'), ('have', 'VB'), ('any', 'DT'), ('answers', 'NNS'), ('However', 'RB'), ('I', 'PRP'), ('think', 'VBP'), ('an', 'DT'), ('inside', 'NN'), ('job', 'NN'), ('has', 'VBZ'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('obvious', 'JJ'), ('solution', 'NN'), ('for', 'IN'), ('how', 'WRB'), ('it', 'PRP'), ('happened', 'VBD'), ('which', 'WDT'), ('will', 'MD'), ('probably', 'RB'), ('be', 'VB'), ('addressed', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('future', 'NN'), ('So', 'IN'), ('far', 'RB'), ('I', 'PRP'), ('love', 'VBP'), ('this', 'DT'), ('show', 'NN'), ('and', 'CC'), ('recommend', 'VB'), ('everyone', 'NN'), ('to', 'TO'), ('watch', 'VB'), ('it', 'PRP'), ('on', 'IN'), ('Netflicks', 'NNS')]
#
# Total No of Nouns: 19
# Total No of Verbs: 23
# Total No of Adjectives: 5
# Total No of Adverbs: 9
# POS tagging for row 293:
# [('The', 'DT'), ('first', 'JJ'), ('episode', 'NN'), ('was', 'VBD'), ('of', 'IN'), ('a', 'DT'), ('high', 'JJ'), ('quality', 'NN'), ('but', 'CC'), ('after', 'IN'), ('a', 'DT'), ('couple', 'NN'), ('of', 'IN'), ('episodes', 'NNS'), ('this', 'DT'), ('show', 'NN'), ('becomes', 'VBZ'), ('3', 'CD'), ('shows', 'VBZ'), ('A', 'NNP'), ('House', 'NNP'), ('Of', 'IN'), ('Cards', 'NNPS'), ('with', 'IN'), ('a', 'DT'), ('too', 'RB'), ('good', 'JJ'), ('always', 'RB'), ('makes', 'VBZ'), ('politically', 'RB'), ('correct', 'JJ'), ('decisions', 'NNS'), ('president', 'NN'), ('He', 'PRP'), ('is', 'VBZ'), ('just', 'RB'), ('not', 'RB'), ('interesting', 'VBG'), ('I', 'PRP'), ('wish', 'VBP'), ('he', 'PRP'), ('w', 'VBZ'), ('s', 'JJ'), ('evil', 'FW'), ('A', 'DT'), ('Homeland', 'NNP'), ('woman', 'NN'), ('who', 'WP'), ('tries', 'VBZ'), ('to', 'TO'), ('save', 'VB'), ('the', 'DT'), ('world', 'NN'), ('on', 'IN'), ('her', 'PRP$'), ('own', 'JJ'), ('She', 'PRP'), ('s', 'VBD'), ('also', 'RB'), ('not', 'RB'), ('interesting', 'JJ'), ('and', 'CC'), ('the', 'DT'), ('action', 'NN'), ('scenes', 'NNS'), ('with', 'IN'), ('her', 'PRP$'), ('are', 'VBP'), ('like', 'IN'), ('the', 'DT'), ('A', 'NNP'), ('team', 'NN'), ('or', 'CC'), ('mcgyver', 'NN'), ('just', 'RB'), ('amateurish', 'JJ'), ('just', 'RB'), ('like', 'IN'), ('the', 'DT'), ('black', 'JJ'), ('screened', 'VBD'), ('beeping', 'VBG'), ('Hollywood', 'NNP'), ('computers', 'NNS'), ('they', 'PRP'), ('use', 'VBP'), ('with', 'IN'), ('awful', 'JJ'), ('animations', 'NNS'), ('Then', 'RB'), ('there', 'EX'), ('is', 'VBZ'), ('the', 'DT'), ('wife', 'NN'), ('and', 'CC'), ('kids', 'NNS'), ('and', 'CC'), ('it', 'PRP'), ('s', 'VBZ'), ('just', 'RB'), ('too', 'RB'), ('sweet', 'JJ'), ('The', 'DT'), ('designated', 'JJ'), ('survivor', 'NN'), ('thing', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('very', 'RB'), ('interesting', 'JJ'), ('story', 'NN'), ('I', 'PRP'), ('wish', 'VBP'), ('there', 'EX'), ('were', 'VBD'), ('flash', 'JJ'), ('back', 'RB'), ('episodes', 'VBZ'), ('why', 'WRB'), ('the', 'DT'), ('attackers', 'NNS'), ('did', 'VBD'), ('it', 'PRP'), ('How', 'NNP'), ('was', 'VBD'), ('the', 'DT'), ('situation', 'NN'), ('before', 'IN'), ('Also', 'RB'), ('make', 'VBP'), ('Keifer', 'NNP'), ('suck', 'JJ'), ('Let', 'NNP'), ('him', 'PRP'), ('make', 'VB'), ('wrong', 'JJ'), ('decisions', 'NNS'), ('be', 'VB'), ('a', 'DT'), ('lousy', 'JJ'), ('husband', 'NN'), ('that', 'WDT'), ('secretly', 'RB'), ('enjoys', 'VBZ'), ('all', 'PDT'), ('this', 'DT'), ('new', 'JJ'), ('power', 'NN')]
#
# Total No of Nouns: 34
# Total No of Verbs: 27
# Total No of Adjectives: 18
# Total No of Adverbs: 16
# POS tagging for row 294:
# [('If', 'IN'), ('ever', 'RB'), ('you', 'PRP'), ('needed', 'VBD'), ('an', 'DT'), ('example', 'NN'), ('of', 'IN'), ('why', 'WRB'), ('TV', 'NN'), ('shows', 'VBZ'), ('work', 'NN'), ('best', 'RB'), ('as', 'IN'), ('serials', 'NNS'), ('look', 'VBP'), ('no', 'DT'), ('further', 'JJR'), ('than', 'IN'), ('Designated', 'VBN'), ('Survivor', 'NNP'), ('Sworn', 'NNP'), ('in', 'IN'), ('as', 'IN'), ('president', 'NN'), ('following', 'VBG'), ('a', 'DT'), ('terrorist', 'JJ'), ('attack', 'NN'), ('Kiefer', 'NNP'), ('Sutherland', 'NNP'), ('s', 'NN'), ('character', 'NN'), ('has', 'VBZ'), ('to', 'TO'), ('face', 'VB'), ('a', 'DT'), ('new', 'JJ'), ('crisis', 'NN'), ('on', 'IN'), ('every', 'DT'), ('episode', 'NN'), ('As', 'IN'), ('the', 'DT'), ('story', 'NN'), ('progresses', 'VBZ'), ('it', 'PRP'), ('becomes', 'VBZ'), ('clear', 'JJ'), ('that', 'IN'), ('there', 'EX'), ('s', 'VBZ'), ('more', 'JJR'), ('than', 'IN'), ('meets', 'VBZ'), ('the', 'DT'), ('eye', 'NN'), ('In', 'IN'), ('addition', 'NN'), ('to', 'TO'), ('Sutherland', 'NNP'), ('there', 'EX'), ('s', 'VBZ'), ('fine', 'JJ'), ('support', 'NN'), ('from', 'IN'), ('Natascha', 'NNP'), ('McElhone', 'NNP'), ('The', 'DT'), ('Truman', 'NNP'), ('Show', 'NNP'), ('Kal', 'NNP'), ('Penn', 'NNP'), ('Harold', 'NNP'), ('Kumar', 'NNP'), ('and', 'CC'), ('others', 'NNS'), ('I', 'PRP'), ('recommend', 'VBP'), ('it', 'PRP')]
#
# Total No of Nouns: 28
# Total No of Verbs: 13
# Total No of Adjectives: 6
# Total No of Adverbs: 2
# POS tagging for row 295:
# [('8', 'CD'), ('episodes', 'NNS'), ('in', 'IN'), ('and', 'CC'), ('I', 'PRP'), ('m', 'VBP'), ('really', 'RB'), ('enjoying', 'VBG'), ('this', 'DT'), ('It', 'PRP'), ('s', 'VBZ'), ('basically', 'RB'), ('24', 'CD'), ('but', 'CC'), ('with', 'IN'), ('Kroger', 'NNP'), ('Sutherland', 'NNP'), ('spending', 'VBG'), ('more', 'JJR'), ('time', 'NN'), ('sat', 'VBD'), ('down', 'RB'), ('think', 'JJ'), ('things', 'NNS'), ('through', 'IN'), ('and', 'CC'), ('being', 'VBG'), ('political', 'JJ'), ('loving', 'NN'), ('while', 'IN'), ('other', 'JJ'), ('younger', 'JJR'), ('or', 'CC'), ('more', 'RBR'), ('vicious', 'JJ'), ('characters', 'NNS'), ('do', 'VBP'), ('all', 'PDT'), ('the', 'DT'), ('running', 'VBG'), ('around', 'RB'), ('and', 'CC'), ('provide', 'VB'), ('the', 'DT'), ('action', 'NN')]
#
# Total No of Nouns: 8
# Total No of Verbs: 9
# Total No of Adjectives: 6
# Total No of Adverbs: 5
# POS tagging for row 296:
# [('This', 'DT'), ('could', 'MD'), ('have', 'VB'), ('been', 'VBN'), ('an', 'DT'), ('excellent', 'JJ'), ('series', 'NN'), ('if', 'IN'), ('they', 'PRP'), ('hadn', 'VBP'), ('t', 'NNS'), ('have', 'VBP'), ('decided', 'VBN'), ('they', 'PRP'), ('were', 'VBD'), ('there', 'EX'), ('to', 'TO'), ('be', 'VB'), ('a', 'DT'), ('shill', 'NN'), ('for', 'IN'), ('a', 'DT'), ('political', 'JJ'), ('party', 'NN'), ('instead', 'RB'), ('of', 'IN'), ('entertainment', 'NN'), ('Especially', 'RB'), ('when', 'WRB'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('the', 'DT'), ('political', 'JJ'), ('stuff', 'NN'), ('was', 'VBD'), ('full', 'JJ'), ('of', 'IN'), ('dishonest', 'JJS'), ('claims', 'NNS'), ('and', 'CC'), ('facts', 'NNS'), ('they', 'PRP'), ('used', 'VBD'), ('to', 'TO'), ('push', 'VB'), ('an', 'DT'), ('ideological', 'JJ'), ('agenda', 'NN')]
#
# Total No of Nouns: 10
# Total No of Verbs: 10
# Total No of Adjectives: 6
# Total No of Adverbs: 2
# POS tagging for row 297:
# [('Intelligent', 'NNP'), ('dramatic', 'JJ'), ('dialogue', 'NN'), ('engaging', 'NN'), ('and', 'CC'), ('endearing', 'VBG'), ('characters', 'NNS'), ('most', 'RBS'), ('episodes', 'NNS'), ('resolve', 'VBP'), ('positively', 'RB'), ('and', 'CC'), ('wonderful', 'JJ'), ('messages', 'NNS'), ('throughout', 'IN'), ('One', 'CD'), ('of', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('series', 'NN'), ('I', 'PRP'), ('ve', 'VBP'), ('watched', 'VBN'), ('in', 'IN'), ('years', 'NNS'), ('Sutherland', 'NNP'), ('s', 'VBD'), ('best', 'JJS'), ('role', 'NN'), ('so', 'RB'), ('far', 'RB'), ('Hats', 'VBZ'), ('off', 'RP')]
#
# Total No of Nouns: 10
# Total No of Verbs: 6
# Total No of Adjectives: 4
# Total No of Adverbs: 4
# POS tagging for row 298:
# [('Overall', 'JJ'), ('like', 'IN'), ('first', 'JJ'), ('two', 'CD'), ('seasons', 'NNS'), ('very', 'RB'), ('well', 'RB'), ('was', 'VBD'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('few', 'JJ'), ('shows', 'NNS'), ('clean', 'VBP'), ('enough', 'RB'), ('to', 'TO'), ('be', 'VB'), ('considered', 'VBN'), ('a', 'DT'), ('family', 'NN'), ('show', 'NN'), ('One', 'CD'), ('episode', 'NN'), ('in', 'IN'), ('after', 'IN'), ('Netflix', 'NNP'), ('took', 'VBD'), ('over', 'RP'), ('and', 'CC'), ('already', 'RB'), ('potty', 'JJ'), ('mouth', 'VBP'), ('The', 'DT'), ('f', 'NN'), ('word', 'NN'), ('and', 'CC'), ('gd', 'NN'), ('word', 'NN'), ('have', 'VBP'), ('added', 'VBN'), ('nothing', 'NN'), ('constructive', 'NN'), ('to', 'TO'), ('the', 'DT'), ('show', 'NN'), ('just', 'RB'), ('now', 'RB'), ('won', 'VBZ'), ('t', 'NN'), ('be', 'VB'), ('watching', 'VBG'), ('any', 'DT'), ('more', 'JJR'), ('due', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('offensive', 'JJ'), ('language', 'NN'), ('Thanks', 'NNS'), ('for', 'IN'), ('ruinous', 'JJ'), ('a', 'DT'), ('good', 'JJ'), ('show', 'NN'), ('Netflix', 'NNP')]
#
# Total No of Nouns: 18
# Total No of Verbs: 11
# Total No of Adjectives: 9
# Total No of Adverbs: 6
# POS tagging for row 299:
# [('At', 'IN'), ('the', 'DT'), ('beginning', 'VBG'), ('it', 'PRP'), ('was', 'VBD'), ('such', 'JJ'), ('an', 'DT'), ('amazing', 'JJ'), ('show', 'NN'), ('but', 'CC'), ('it', 'PRP'), ('gets', 'VBZ'), ('worse', 'JJR'), ('every', 'DT'), ('season', 'NN'), ('especially', 'RB'), ('season', 'NN'), ('3', 'CD'), ('when', 'WRB'), ('netflix', 'NN'), ('picked', 'VBD'), ('it', 'PRP'), ('up', 'RP')]
#
# Total No of Nouns: 4
# Total No of Verbs: 4
# Total No of Adjectives: 3
# Total No of Adverbs: 1
# POS tagging for row 300:
# [('Designated', 'VBN'), ('Survivor', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('only', 'JJ'), ('new', 'JJ'), ('show', 'NN'), ('of', 'IN'), ('the', 'DT'), ('season', 'NN'), ('I', 'PRP'), ('have', 'VBP'), ('any', 'DT'), ('interest', 'NN'), ('in', 'IN'), ('watching', 'VBG'), ('The', 'DT'), ('show', 'NN'), ('concerns', 'VBZ'), ('a', 'DT'), ('terror', 'NN'), ('attack', 'NN'), ('during', 'IN'), ('the', 'DT'), ('State', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Union', 'NNP'), ('address', 'NN'), ('that', 'WDT'), ('wipes', 'VBZ'), ('out', 'RP'), ('the', 'DT'), ('President', 'NNP'), ('Vice', 'NNP'), ('President', 'NNP'), ('the', 'DT'), ('House', 'NNP'), ('the', 'DT'), ('Senate', 'NNP'), ('and', 'CC'), ('other', 'JJ'), ('high', 'JJ'), ('level', 'JJ'), ('government', 'NN'), ('officials', 'NNS'), ('who', 'WP'), ('are', 'VBP'), ('in', 'IN'), ('the', 'DT'), ('Capitol', 'NNP'), ('Building', 'NNP'), ('at', 'IN'), ('that', 'DT'), ('time', 'NN'), ('When', 'WRB'), ('there', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('large', 'JJ'), ('assembly', 'NN'), ('of', 'IN'), ('President', 'NNP'), ('VP', 'NNP'), ('House', 'NNP'), ('Senate', 'NNP'), ('etc', 'FW'), ('one', 'CD'), ('person', 'NN'), ('is', 'VBZ'), ('chosen', 'VBN'), ('to', 'TO'), ('stay', 'VB'), ('behind', 'IN'), ('in', 'IN'), ('the', 'DT'), ('event', 'NN'), ('of', 'IN'), ('just', 'RB'), ('such', 'PDT'), ('a', 'DT'), ('thing', 'NN'), ('occurring', 'NN'), ('After', 'IN'), ('the', 'DT'), ('show', 'NN'), ('premiered', 'VBD'), ('I', 'PRP'), ('did', 'VBD'), ('see', 'VB'), ('a', 'DT'), ('news', 'NN'), ('report', 'NN'), ('about', 'IN'), ('this', 'DT'), ('and', 'CC'), ('apparently', 'RB'), ('it', 'PRP'), ('is', 'VBZ'), ('true', 'JJ'), ('Makes', 'NNP'), ('sense', 'NN'), ('The', 'DT'), ('designated', 'VBN'), ('survivor', 'NN'), ('in', 'IN'), ('this', 'DT'), ('case', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('Secretary', 'NNP'), ('of', 'IN'), ('Housing', 'NNP'), ('and', 'CC'), ('Urban', 'NNP'), ('Development', 'NNP'), ('Tom', 'NNP'), ('Kirkman', 'NNP'), ('Kiefer', 'NNP'), ('Sutherland', 'NNP'), ('He', 'PRP'), ('is', 'VBZ'), ('11th', 'CD'), ('in', 'IN'), ('line', 'NN'), ('of', 'IN'), ('succession', 'NN'), ('but', 'CC'), ('he', 'PRP'), ('moves', 'VBZ'), ('up', 'RB'), ('to', 'TO'), ('the', 'DT'), ('top', 'NN'), ('after', 'IN'), ('the', 'DT'), ('attack', 'NN'), ('No', 'NNP'), ('one', 'NN'), ('finds', 'VBZ'), ('him', 'PRP'), ('qualified', 'JJ'), ('and', 'CC'), ('in', 'IN'), ('fact', 'NN'), ('some', 'DT'), ('people', 'NNS'), ('refuse', 'VBP'), ('to', 'TO'), ('follow', 'VB'), ('his', 'PRP$'), ('orders', 'NNS'), ('However', 'RB'), ('Kirkman', 'NNP'), ('is', 'VBZ'), ('stronger', 'JJR'), ('than', 'IN'), ('they', 'PRP'), ('know', 'VBP'), ('even', 'RB'), ('if', 'IN'), ('he', 'PRP'), ('is', 'VBZ'), ('more', 'RBR'), ('deliberate', 'JJ'), ('in', 'IN'), ('making', 'VBG'), ('decisions', 'NNS'), ('He', 'PRP'), ('is', 'VBZ'), ('also', 'RB'), ('a', 'DT'), ('caring', 'VBG'), ('individual', 'NN'), ('who', 'WP'), ('wants', 'VBZ'), ('to', 'TO'), ('live', 'VB'), ('up', 'RP'), ('to', 'TO'), ('his', 'PRP$'), ('responsibilities', 'NNS'), ('and', 'CC'), ('serve', 'VB'), ('the', 'DT'), ('people', 'NNS'), ('It', 'PRP'), ('s', 'VBD'), ('a', 'DT'), ('tough', 'JJ'), ('adjustment', 'NN'), ('for', 'IN'), ('a', 'DT'), ('married', 'JJ'), ('man', 'NN'), ('with', 'IN'), ('two', 'CD'), ('children', 'NNS'), ('who', 'WP'), ('previously', 'RB'), ('had', 'VBD'), ('a', 'DT'), ('very', 'RB'), ('different', 'JJ'), ('job', 'NN'), ('His', 'PRP$'), ('first', 'JJ'), ('order', 'NN'), ('of', 'IN'), ('business', 'NN'), ('is', 'VBZ'), ('finding', 'VBG'), ('out', 'RP'), ('who', 'WP'), ('attacked', 'VBD'), ('the', 'DT'), ('U', 'NNP'), ('S', 'NNP'), ('as', 'IN'), ('the', 'DT'), ('Joint', 'NNP'), ('Chiefs', 'NNP'), ('of', 'IN'), ('Staff', 'NNP'), ('are', 'VBP'), ('eager', 'JJ'), ('to', 'TO'), ('go', 'VB'), ('after', 'IN'), ('whom', 'WP'), ('they', 'PRP'), ('believe', 'VBP'), ('is', 'VBZ'), ('responsible', 'JJ'), ('This', 'DT'), ('may', 'MD'), ('be', 'VB'), ('a', 'DT'), ('problem' ...
#
# Total No of Nouns: 110
# Total No of Verbs: 61
# Total No of Adjectives: 30
# Total No of Adverbs: 16
# POS tagging for row 301:
# [('I', 'PRP'), ('enjoyed', 'VBD'), ('the', 'DT'), ('first', 'JJ'), ('two', 'CD'), ('seasons', 'NNS'), ('of', 'IN'), ('Designated', 'NNP'), ('Survivor', 'NNP'), ('it', 'PRP'), ('was', 'VBD'), ('entertaining', 'VBG'), ('and', 'CC'), ('kept', 'VB'), ('your', 'PRP$'), ('interest', 'NN'), ('If', 'IN'), ('your', 'PRP$'), ('a', 'DT'), ('24', 'CD'), ('fan', 'NN'), ('you', 'PRP'), ('will', 'MD'), ('enjoy', 'VB'), ('the', 'DT'), ('first', 'JJ'), ('two', 'CD'), ('seasons', 'NNS'), ('it', 'PRP'), ('s', 'VBZ'), ('basically', 'RB'), ('if', 'IN'), ('Jack', 'NNP'), ('Bauer', 'NNP'), ('became', 'VBD'), ('president', 'NN'), ('The', 'DT'), ('third', 'JJ'), ('season', 'NN'), ('it', 'PRP'), ('fell', 'VBD'), ('apart', 'RB'), ('with', 'IN'), ('the', 'DT'), ('removal', 'NN'), ('of', 'IN'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('cast', 'NN'), ('with', 'IN'), ('no', 'DT'), ('explanation', 'NN'), ('They', 'PRP'), ('also', 'RB'), ('added', 'VBD'), ('lots', 'NNS'), ('of', 'IN'), ('unnecessary', 'JJ'), ('cussing', 'NN'), ('that', 'WDT'), ('did', 'VBD'), ('not', 'RB'), ('fit', 'VB'), ('the', 'DT'), ('vibe', 'NN'), ('it', 'PRP'), ('totally', 'RB'), ('changed', 'VBD'), ('the', 'DT'), ('mood', 'NN'), ('of', 'IN'), ('the', 'DT'), ('show', 'NN')]
#
# Total No of Nouns: 18
# Total No of Verbs: 12
# Total No of Adjectives: 4
# Total No of Adverbs: 5
# POS tagging for row 302:
# [('Season', 'NNP'), ('One', 'CD'), ('and', 'CC'), ('Two', 'CD'), ('were', 'VBD'), ('fantastic', 'JJ'), ('Interesting', 'NNP'), ('gripping', 'VBG'), ('great', 'JJ'), ('cast', 'NN'), ('and', 'CC'), ('production', 'NN'), ('I', 'PRP'), ('couldn', 'VBP'), ('t', 'JJ'), ('wait', 'NN'), ('for', 'IN'), ('the', 'DT'), ('next', 'JJ'), ('episode', 'NN'), ('After', 'IN'), ('Netflix', 'NNP'), ('took', 'VBD'), ('over', 'RP'), ('Season', 'NNP'), ('Three', 'NNP'), ('I', 'PRP'), ('stopped', 'VBD'), ('watching', 'VBG'), ('after', 'IN'), ('about', 'IN'), ('one', 'CD'), ('third', 'NN'), ('of', 'IN'), ('the', 'DT'), ('episodes', 'NNS'), ('Season', 'NNP'), ('Three', 'NNP'), ('is', 'VBZ'), ('obsessed', 'VBN'), ('and', 'CC'), ('strategized', 'VBN'), ('with', 'IN'), ('misguided', 'JJ'), ('identity', 'NN'), ('politics', 'NNS'), ('politically', 'RB'), ('correct', 'VBP'), ('content', 'NN'), ('and', 'CC'), ('crass', 'NN'), ('language', 'NN'), ('The', 'DT'), ('screenplays', 'NNS'), ('for', 'IN'), ('Season', 'NNP'), ('Three', 'NNP'), ('are', 'VBP'), ('amateurish', 'JJ'), ('and', 'CC'), ('nowhere', 'JJ'), ('match', 'NN'), ('those', 'DT'), ('of', 'IN'), ('Season', 'NNP'), ('One', 'NNP'), ('and', 'CC'), ('Two', 'CD'), ('Strange', 'NNP'), ('when', 'WRB'), ('Netflix', 'NNP'), ('produces', 'VBZ'), ('things', 'NNS'), ('get', 'VBP'), ('sleazy', 'JJ')]
#
# Total No of Nouns: 27
# Total No of Verbs: 13
# Total No of Adjectives: 8
# Total No of Adverbs: 1
# POS tagging for row 303:
# [('I', 'PRP'), ('really', 'RB'), ('liked', 'VBD'), ('Designated', 'NNP'), ('Survivor', 'NNP'), ('for', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('two', 'CD'), ('seasons', 'NNS'), ('gave', 'VBD'), ('them', 'PRP'), ('a', 'DT'), ('rating', 'NN'), ('of', 'IN'), ('9', 'CD'), ('and', 'CC'), ('was', 'VBD'), ('happy', 'JJ'), ('when', 'WRB'), ('they', 'PRP'), ('announced', 'VBD'), ('that', 'IN'), ('Netfkix', 'NNP'), ('was', 'VBD'), ('going', 'VBG'), ('to', 'TO'), ('do', 'VB'), ('a', 'DT'), ('thrid', 'NN'), ('season', 'NN'), ('but', 'CC'), ('not', 'RB'), ('only', 'RB'), ('is', 'VBZ'), ('this', 'DT'), ('season', 'NN'), ('dull', 'NN'), ('do', 'VBP'), ('they', 'PRP'), ('have', 'VB'), ('new', 'JJ'), ('script', 'NN'), ('writers', 'NNS'), ('but', 'CC'), ('they', 'PRP'), ('have', 'VBP'), ('added', 'VBN'), ('crude', 'NN'), ('language', 'NN'), ('and', 'CC'), ('graphic', 'JJ'), ('sex', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('disappointing', 'VBG'), ('The', 'DT'), ('story', 'NN'), ('line', 'NN'), ('of', 'IN'), ('Kirkman', 'NNP'), ('running', 'VBG'), ('for', 'IN'), ('president', 'NN'), ('is', 'VBZ'), ('done', 'VBN'), ('in', 'IN'), ('a', 'DT'), ('lousy', 'JJ'), ('way', 'NN'), ('The', 'DT'), ('new', 'JJ'), ('characters', 'NNS'), ('are', 'VBP'), ('obnoxious', 'JJ'), ('straight', 'RB'), ('down', 'IN'), ('the', 'DT'), ('line', 'NN'), ('even', 'RB'), ('though', 'IN'), ('the', 'DT'), ('actors', 'NNS'), ('who', 'WP'), ('play', 'VBP'), ('them', 'PRP'), ('are', 'VBP'), ('for', 'IN'), ('the', 'DT'), ('most', 'JJS'), ('part', 'NN'), ('decent', 'NN'), ('actors', 'NNS'), ('Overacted', 'VBD'), ('and', 'CC'), ('with', 'IN'), ('the', 'DT'), ('feeling', 'NN'), ('that', 'IN'), ('everyone', 'NN'), ('except', 'IN'), ('Sutherland', 'NNP'), ('are', 'VBP'), ('just', 'RB'), ('phoning', 'VBG'), ('it', 'PRP'), ('in', 'IN'), ('This', 'DT'), ('is', 'VBZ'), ('turning', 'VBG'), ('me', 'PRP'), ('off', 'RP'), ('pretty', 'RB'), ('quickly', 'RB'), ('How', 'NNP'), ('could', 'MD'), ('Netflix', 'VB'), ('ruin', 'VB'), ('what', 'WP'), ('was', 'VBD'), ('a', 'DT'), ('decent', 'JJ'), ('series', 'NN'), ('Those', 'DT'), ('of', 'IN'), ('us', 'PRP'), ('who', 'WP'), ('were', 'VBD'), ('watching', 'VBG'), ('it', 'PRP'), ('most', 'RBS'), ('likely', 'JJ'), ('didn', 'JJ'), ('t', 'NN'), ('watch', 'VBP'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('House', 'NNP'), ('of', 'IN'), ('Cards', 'NNP'), ('and', 'CC'), ('that', 'DT'), ('is', 'VBZ'), ('not', 'RB'), ('what', 'WP'), ('we', 'PRP'), ('want', 'VBP')]
#
# Total No of Nouns: 34
# Total No of Verbs: 33
# Total No of Adjectives: 11
# Total No of Adverbs: 10
# POS tagging for row 304:
# [('I', 'PRP'), ('ve', 'VBP'), ('liked', 'VBD'), ('this', 'DT'), ('show', 'NN'), ('even', 'RB'), ('though', 'IN'), ('it', 'PRP'), ('s', 'VBZ'), ('a', 'DT'), ('little', 'JJ'), ('liberal', 'JJ'), ('for', 'IN'), ('me', 'PRP'), ('I', 'PRP'), ('was', 'VBD'), ('excited', 'VBN'), ('Netflix', 'NNP'), ('picked', 'VBD'), ('it', 'PRP'), ('up', 'RP'), ('after', 'IN'), ('being', 'VBG'), ('cancelled', 'VBN'), ('Why', 'WRB'), ('did', 'VBD'), ('Netflix', 'RB'), ('have', 'VB'), ('to', 'TO'), ('add', 'VB'), ('the', 'DT'), ('cursing', 'VBG'), ('The', 'DT'), ('show', 'NN'), ('was', 'VBD'), ('fine', 'JJ'), ('without', 'IN'), ('it', 'PRP'), ('Language', 'NNP'), ('doesn', 'VBZ'), ('t', 'JJ'), ('add', 'VB'), ('anything', 'NN'), ('to', 'TO'), ('the', 'DT'), ('quality', 'NN'), ('of', 'IN'), ('the', 'DT'), ('show', 'NN'), ('I', 'PRP'), ('know', 'VBP'), ('everyone', 'NN'), ('thinks', 'VBZ'), ('it', 'PRP'), ('makes', 'VBZ'), ('it', 'PRP'), ('more', 'RBR'), ('realistic', 'JJ'), ('but', 'CC'), ('I', 'PRP'), ('disagree', 'VBP'), ('It', 'PRP'), ('just', 'RB'), ('isn', 'VB'), ('t', 'NN'), ('needed', 'VBN')]
#
# Total No of Nouns: 9
# Total No of Verbs: 21
# Total No of Adjectives: 5
# Total No of Adverbs: 4
# POS tagging for row 305:
# [('This', 'DT'), ('show', 'NN'), ('is', 'VBZ'), ('one', 'CD'), ('of', 'IN'), ('my', 'PRP$'), ('favourite', 'JJ'), ('Netflix', 'NNP'), ('Originals', 'NNP'), ('It', 'PRP'), ('kind', 'NN'), ('of', 'IN'), ('combines', 'NNS'), ('House', 'NNP'), ('of', 'IN'), ('Cards', 'NNP'), ('2013', 'CD'), ('with', 'IN'), ('24', 'CD'), ('2001', 'CD'), ('really', 'RB'), ('well', 'RB'), ('with', 'IN'), ('it', 'PRP'), ('being', 'VBG'), ('half', 'JJ'), ('political', 'JJ'), ('drama', 'NN'), ('and', 'CC'), ('half', 'JJ'), ('action', 'NN'), ('thriller', 'IN'), ('All', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('main', 'JJ'), ('cast', 'NN'), ('play', 'NN'), ('such', 'JJ'), ('amazing', 'JJ'), ('likeable', 'JJ'), ('but', 'CC'), ('flawed', 'VBD'), ('characters', 'NNS'), ('Season', 'NNP'), ('One', 'CD'), ('is', 'VBZ'), ('by', 'IN'), ('far', 'RB'), ('the', 'DT'), ('best', 'JJS'), ('because', 'IN'), ('you', 'PRP'), ('just', 'RB'), ('had', 'VBD'), ('no', 'DT'), ('idea', 'NN'), ('where', 'WRB'), ('it', 'PRP'), ('was', 'VBD'), ('going', 'VBG'), ('season', 'NN'), ('two', 'CD'), ('kept', 'VBD'), ('the', 'DT'), ('suspense', 'NN'), ('with', 'IN'), ('a', 'DT'), ('different', 'JJ'), ('story', 'NN'), ('every', 'DT'), ('week', 'NN'), ('but', 'CC'), ('still', 'RB'), ('had', 'VBD'), ('long', 'JJ'), ('running', 'NN'), ('stories', 'NNS'), ('Season', 'NNP'), ('three', 'CD'), ('however', 'RB'), ('wasn', 'VBP'), ('t', 'NNS'), ('that', 'WDT'), ('good', 'VBD'), ('It', 'PRP'), ('had', 'VBD'), ('some', 'DT'), ('good', 'JJ'), ('moments', 'NNS'), ('but', 'CC'), ('it', 'PRP'), ('just', 'RB'), ('felt', 'VBD'), ('like', 'IN'), ('a', 'DT'), ('very', 'RB'), ('different', 'JJ'), ('show', 'NN')]
#
# Total No of Nouns: 25
# Total No of Verbs: 13
# Total No of Adjectives: 13
# Total No of Adverbs: 8
# POS tagging for row 306:
# [('Started', 'VBN'), ('off', 'RP'), ('brilliant', 'NN'), ('season', 'NN'), ('one', 'CD'), ('is', 'VBZ'), ('fantastic', 'JJ'), ('Season', 'NNP'), ('2', 'CD'), ('is', 'VBZ'), ('just', 'RB'), ('as', 'RB'), ('good', 'JJ'), ('But', 'CC'), ('the', 'DT'), ('whole', 'JJ'), ('tone', 'NN'), ('of', 'IN'), ('the', 'DT'), ('show', 'NN'), ('changes', 'VBZ'), ('in', 'IN'), ('season', 'NN'), ('3', 'CD'), ('ruined', 'VBD'), ('it', 'PRP'), ('for', 'IN'), ('me', 'PRP'), ('As', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('only', 'RB'), ('ten', 'JJ'), ('episodes', 'NNS'), ('I', 'PRP'), ('stuck', 'VBP'), ('with', 'IN'), ('it', 'PRP'), ('it', 'PRP'), ('just', 'RB'), ('got', 'VBD'), ('worse', 'JJR'), ('It', 'PRP'), ('was', 'VBD'), ('like', 'IN'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('characters', 'NNS'), ('personalities', 'NNS'), ('completely', 'RB'), ('changed', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('third', 'JJ'), ('season', 'NN'), ('What', 'WP'), ('s', 'VBZ'), ('great', 'JJ'), ('about', 'IN'), ('seasons', 'NNS'), ('one', 'CD'), ('and', 'CC'), ('two', 'CD'), ('is', 'VBZ'), ('it', 'PRP'), ('s', 'RB'), ('just', 'RB'), ('as', 'IN'), ('it', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('if', 'IN'), ('Jack', 'NNP'), ('Bauer', 'NNP'), ('ever', 'RB'), ('became', 'VBD'), ('president', 'NN'), ('loved', 'VBD'), ('that', 'IN'), ('The', 'DT'), ('acting', 'NN'), ('is', 'VBZ'), ('great', 'JJ'), ('in', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('two', 'CD'), ('seasons', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('storylines', 'NNS'), ('are', 'VBP'), ('great', 'JJ'), ('quickest', 'JJS'), ('I', 'PRP'), ('ve', 'VBP'), ('ever', 'RB'), ('got', 'VBN'), ('through', 'IN'), ('so', 'RB'), ('many', 'JJ'), ('episodes', 'NNS'), ('of', 'IN'), ('any', 'DT'), ('show', 'NN'), ('So', 'RB'), ('to', 'TO'), ('sum', 'VB'), ('up', 'RP'), ('definitely', 'RB'), ('worth', 'IN'), ('a', 'DT'), ('watch', 'NN'), ('but', 'CC'), ('probably', 'RB'), ('best', 'JJS'), ('to', 'TO'), ('forget', 'VB'), ('they', 'PRP'), ('ever', 'RB'), ('made', 'VBD'), ('a', 'DT'), ('third', 'JJ'), ('season', 'NN')]
#
# Total No of Nouns: 21
# Total No of Verbs: 22
# Total No of Adjectives: 14
# Total No of Adverbs: 14
# POS tagging for row 307:
# [('This', 'DT'), ('show', 'NN'), ('which', 'WDT'), ('I', 'PRP'), ('stumbled', 'VBD'), ('upon', 'RP'), ('when', 'WRB'), ('trying', 'VBG'), ('to', 'TO'), ('find', 'VB'), ('something', 'NN'), ('to', 'TO'), ('watch', 'VB'), ('grabbed', 'FW'), ('me', 'PRP'), ('right', 'VBD'), ('off', 'RP'), ('the', 'DT'), ('cuff', 'NN'), ('Full', 'NNP'), ('of', 'IN'), ('twists', 'NNS'), ('and', 'CC'), ('turns', 'VBZ'), ('incredible', 'JJ'), ('storylines', 'NNS'), ('and', 'CC'), ('great', 'JJ'), ('actors', 'NNS'), ('I', 'PRP'), ('am', 'VBP'), ('sold', 'VBN'), ('From', 'IN'), ('terrorists', 'NNS'), ('to', 'TO'), ('conspiracies', 'NNS'), ('to', 'TO'), ('family', 'NN'), ('and', 'CC'), ('finally', 'RB'), ('the', 'DT'), ('incredible', 'JJ'), ('conflicts', 'NNS'), ('going', 'VBG'), ('on', 'IN'), ('within', 'IN'), ('the', 'DT'), ('country', 'NN'), ('Watch', 'VBD'), ('it', 'PRP'), ('Now', 'RB')]
#
# Total No of Nouns: 12
# Total No of Verbs: 10
# Total No of Adjectives: 3
# Total No of Adverbs: 2
# POS tagging for row 308:
# [('I', 'PRP'), ('ve', 'VBP'), ('just', 'RB'), ('binge', 'NN'), ('watched', 'VBD'), ('it', 'PRP'), ('up', 'RP'), ('to', 'TO'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('Episode', 'NNP'), ('18', 'CD'), ('The', 'DT'), ('initial', 'JJ'), ('premise', 'NN'), ('is', 'VBZ'), ('interesting', 'VBG'), ('whether', 'IN'), ('or', 'CC'), ('not', 'RB'), ('it', 'PRP'), ('s', 'VBZ'), ('actually', 'RB'), ('based', 'VBN'), ('in', 'IN'), ('reality', 'NN'), ('You', 'PRP'), ('always', 'RB'), ('need', 'VBP'), ('to', 'TO'), ('grant', 'VB'), ('some', 'DT'), ('leeway', 'NN'), ('with', 'IN'), ('initial', 'JJ'), ('premises', 'NNS'), ('especially', 'RB'), ('these', 'DT'), ('days', 'NNS'), ('I', 'PRP'), ('stopped', 'VBD'), ('watching', 'VBG'), ('24', 'CD'), ('after', 'IN'), ('the', 'DT'), ('second', 'JJ'), ('season', 'NN'), ('because', 'IN'), ('I', 'PRP'), ('found', 'VBD'), ('it', 'PRP'), ('too', 'RB'), ('infantile', 'JJ'), ('and', 'CC'), ('silly', 'JJ'), ('I', 'PRP'), ('did', 'VBD'), ('watch', 'VB'), ('The', 'DT'), ('West', 'NNP'), ('Wing', 'NNP'), ('through', 'IN'), ('to', 'TO'), ('the', 'DT'), ('end', 'NN'), ('This', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('sort', 'NN'), ('of', 'IN'), ('24', 'CD'), ('meets', 'NNS'), ('The', 'DT'), ('West', 'NNP'), ('Wing', 'VBG'), ('The', 'DT'), ('show', 'NN'), ('lets', 'VBZ'), ('itself', 'PRP'), ('down', 'RP'), ('with', 'IN'), ('too', 'RB'), ('many', 'JJ'), ('loving', 'VBG'), ('gazes', 'NNS'), ('between', 'IN'), ('the', 'DT'), ('President', 'NNP'), ('and', 'CC'), ('his', 'PRP$'), ('wife', 'NN'), ('does', 'VBZ'), ('she', 'PRP'), ('have', 'VB'), ('any', 'DT'), ('flaws', 'NNS'), ('at', 'IN'), ('all', 'DT'), ('some', 'DT'), ('terribly', 'RB'), ('clunky', 'JJ'), ('lines', 'NNS'), ('and', 'CC'), ('worst', 'JJS'), ('of', 'IN'), ('all', 'PDT'), ('the', 'DT'), ('relentless', 'NN'), ('US', 'NNP'), ('Patriot', 'NNP'), ('buzz', 'NN'), ('word', 'NN'), ('laden', 'NN'), ('speeches', 'VBZ'), ('The', 'DT'), ('American', 'JJ'), ('people', 'NNS'), ('deserve', 'VBP'), ('Rebuilding', 'VBG'), ('our', 'PRP$'), ('amazing', 'JJ'), ('nation', 'NN'), ('Rebuilding', 'VBG'), ('our', 'PRP$'), ('fantastic', 'JJ'), ('Government', 'NNP'), ('There', 'EX'), ('s', 'VBZ'), ('no', 'DT'), ('mention', 'NN'), ('of', 'IN'), ('lobbyists', 'NNS'), ('or', 'CC'), ('Corporate', 'NNP'), ('involvement', 'NN'), ('in', 'IN'), ('Government', 'NNP'), ('There', 'EX'), ('s', 'VBZ'), ('no', 'DT'), ('mention', 'NN'), ('of', 'IN'), ('the', 'DT'), ('profound', 'NN'), ('disconnect', 'NN'), ('between', 'IN'), ('citizen', 'NN'), ('and', 'CC'), ('Government', 'NNP'), ('that', 'WDT'), ('is', 'VBZ'), ('a', 'DT'), ('feature', 'NN'), ('of', 'IN'), ('contemporary', 'JJ'), ('politics', 'NNS'), ('The', 'DT'), ('various', 'JJ'), ('third', 'JJ'), ('rails', 'NNS'), ('of', 'IN'), ('US', 'NNP'), ('politics', 'NNS'), ('are', 'VBP'), ('briefly', 'NN'), ('mentioned', 'VBD'), ('It', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('show', 'NN'), ('about', 'IN'), ('a', 'DT'), ('fantasy', 'NN'), ('America', 'NNP'), ('and', 'CC'), ('a', 'DT'), ('fantasy', 'JJ'), ('American', 'JJ'), ('Government', 'NNP'), ('It', 'PRP'), ('s', 'VBD'), ('the', 'DT'), ('TV', 'NN'), ('Show', 'NNP'), ('version', 'NN'), ('of', 'IN'), ('America', 'NNP'), ('that', 'WDT'), ('is', 'VBZ'), ('challenged', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('initial', 'JJ'), ('events', 'NNS'), ('and', 'CC'), ('it', 'PRP'), ('responds', 'VBZ'), ('the', 'DT'), ('way', 'NN'), ('TV', 'NN'), ('Show', 'NNP'), ('script', 'VBZ'), ('writers', 'NNS'), ('think', 'VBP'), ('such', 'PDT'), ('a', 'DT'), ('world', 'NN'), ('would', 'MD'), ('respond', 'VB'), ('Having', 'NNP'), ('said', 'VBD'), ('all', 'DT'), ('that', 'IN'), ('it', 'PRP'), ('moves', 'VBZ'), ('reasonably', 'RB'), ('quickly', 'RB'), ('and', 'CC'), ('the', 'DT'), ('split', 'NN'), ('between', 'IN'), ('the', 'DT'), ('two', 'CD'), ('story', 'NN'), ('arcs', 'NN'), ('is', 'VBZ'), ('well', 'RB'), ('handled', 'VBN'), ('and', 'CC'), ('engaging', 'VBG'), ('The', 'DT'), ('only', 'JJ'), ('caveat', 'NN'), ('is', 'VBZ'), (' ...
#
# Total No of Nouns: 73
# Total No of Verbs: 50
# Total No of Adjectives: 24
# Total No of Adverbs: 15
# POS tagging for row 309:
# [('I', 'PRP'), ('wish', 'VBP'), ('Tom', 'NNP'), ('Kirkman', 'NNP'), ('were', 'VBD'), ('our', 'PRP$'), ('actual', 'JJ'), ('president', 'NN'), ('Great', 'NNP'), ('characters', 'NNS'), ('and', 'CC'), ('keeps', 'VBZ'), ('you', 'PRP'), ('going', 'VBG')]
#
# Total No of Nouns: 5
# Total No of Verbs: 4
# Total No of Adjectives: 1
# Total No of Adverbs: 0
# POS tagging for row 310:
# [('Nothing', 'NN'), ('is', 'VBZ'), ('added', 'VBN'), ('by', 'IN'), ('Netflix', 'NNP'), ('s', 'JJ'), ('inclusion', 'NN'), ('of', 'IN'), ('profanity', 'NN'), ('for', 'IN'), ('this', 'DT'), ('new', 'JJ'), ('season', 'NN'), ('Just', 'NNP'), ('because', 'IN'), ('you', 'PRP'), ('Can', 'MD'), ('doesn', 'VB'), ('t', 'JJ'), ('mean', 'NN'), ('you', 'PRP'), ('Should', 'VBP'), ('A', 'DT'), ('famous', 'JJ'), ('adage', 'NN'), ('that', 'WDT'), ('applies', 'VBZ'), ('especially', 'RB'), ('when', 'WRB'), ('it', 'PRP'), ('affects', 'VBZ'), ('the', 'DT'), ('tenor', 'NN'), ('and', 'CC'), ('tone', 'NN'), ('of', 'IN'), ('a', 'DT'), ('show', 'NN'), ('that', 'WDT'), ('survived', 'VBD'), ('without', 'IN'), ('It', 'PRP'), ('is', 'VBZ'), ('actually', 'RB'), ('distracting', 'JJ'), ('and', 'CC'), ('takes', 'VBZ'), ('away', 'RB'), ('from', 'IN'), ('the', 'DT'), ('enjoyment', 'NN'), ('of', 'IN'), ('the', 'DT'), ('show', 'NN')]
#
# Total No of Nouns: 13
# Total No of Verbs: 9
# Total No of Adjectives: 5
# Total No of Adverbs: 3
# POS tagging for row 311:
# [('The', 'DT'), ('pilot', 'NN'), ('episode', 'NN'), ('was', 'VBD'), ('intriguing', 'VBG'), ('but', 'CC'), ('as', 'IN'), ('Designated', 'NNP'), ('Survivor', 'NNP'), ('just', 'RB'), ('watched', 'VBD'), ('episode', 'RB'), ('5', 'CD'), ('goes', 'VBZ'), ('on', 'IN'), ('it', 'PRP'), ('s', 'VBZ'), ('really', 'RB'), ('hitting', 'VBG'), ('it', 'PRP'), ('s', 'JJ'), ('stride', 'JJ'), ('Kiefer', 'NNP'), ('s', 'NN'), ('acting', 'NN'), ('is', 'VBZ'), ('compelling', 'VBG'), ('and', 'CC'), ('all', 'DT'), ('of', 'IN'), ('the', 'DT'), ('characters', 'NNS'), ('are', 'VBP'), ('beginning', 'VBG'), ('to', 'TO'), ('get', 'VB'), ('fleshed', 'VBN'), ('out', 'RP'), ('as', 'IN'), ('the', 'DT'), ('story', 'NN'), ('begins', 'VBZ'), ('to', 'TO'), ('come', 'VB'), ('together', 'RB'), ('The', 'DT'), ('idea', 'NN'), ('of', 'IN'), ('an', 'DT'), ('every', 'DT'), ('man', 'NN'), ('becoming', 'VBG'), ('President', 'NNP'), ('is', 'VBZ'), ('interesting', 'JJ'), ('as', 'IN'), ('he', 'PRP'), ('copes', 'VBZ'), ('with', 'IN'), ('the', 'DT'), ('difficult', 'JJ'), ('choices', 'NNS'), ('he', 'PRP'), ('has', 'VBZ'), ('to', 'TO'), ('make', 'VB'), ('and', 'CC'), ('the', 'DT'), ('effects', 'NNS'), ('his', 'PRP$'), ('new', 'JJ'), ('job', 'NN'), ('have', 'VBP'), ('on', 'IN'), ('him', 'PRP'), ('and', 'CC'), ('his', 'PRP$'), ('family', 'NN'), ('Actually', 'RB'), ('showing', 'VBG'), ('the', 'DT'), ('incredible', 'JJ'), ('toll', 'NN'), ('that', 'IN'), ('making', 'VBG'), ('life', 'NN'), ('and', 'CC'), ('death', 'NN'), ('decisions', 'NNS'), ('a', 'DT'), ('decent', 'JJ'), ('man', 'NN'), ('who', 'WP'), ('is', 'VBZ'), ('president', 'NN'), ('has', 'VBZ'), ('to', 'TO'), ('make', 'VB'), ('is', 'VBZ'), ('so', 'RB'), ('enlightening', 'JJ'), ('and', 'CC'), ('Kiefer', 'NNP'), ('is', 'VBZ'), ('masterful', 'JJ'), ('at', 'IN'), ('portraying', 'VBG'), ('the', 'DT'), ('pathos', 'NN'), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('the', 'DT'), ('joy', 'NN'), ('Adding', 'VBG'), ('the', 'DT'), ('conspiracy', 'NN'), ('suspense', 'NN'), ('to', 'TO'), ('the', 'DT'), ('mix', 'NN'), ('makes', 'VBZ'), ('it', 'PRP'), ('edge', 'NN'), ('of', 'IN'), ('your', 'PRP$'), ('seat', 'NN'), ('viewing', 'VBG'), ('This', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('first', 'JJ'), ('new', 'JJ'), ('show', 'NN'), ('in', 'IN'), ('a', 'DT'), ('long', 'JJ'), ('time', 'NN'), ('that', 'IN'), ('I', 'PRP'), ('actually', 'RB'), ('look', 'VBP'), ('forward', 'RB'), ('to', 'TO'), ('watching', 'VBG')]
#
# Total No of Nouns: 32
# Total No of Verbs: 34
# Total No of Adjectives: 12
# Total No of Adverbs: 10
# POS tagging for row 312:
# ...
#
# Total No of Nouns: 34
# Total No of Verbs: 33
# Total No of Adjectives: 11
# Total No of Adverbs: 10
# POS tagging for row 994:
# [('I', 'PRP'), ('ve', 'VBP'), ('liked', 'VBD'), ('this', 'DT'), ('show', 'NN'), ('even', 'RB'), ('though', 'IN'), ('it', 'PRP'), ('s', 'VBZ'), ('a', 'DT'), ('little', 'JJ'), ('liberal', 'JJ'), ('for', 'IN'), ('me', 'PRP'), ('I', 'PRP'), ('was', 'VBD'), ('excited', 'VBN'), ('Netflix', 'NNP'), ('picked', 'VBD'), ('it', 'PRP'), ('up', 'RP'), ('after', 'IN'), ('being', 'VBG'), ('cancelled', 'VBN'), ('Why', 'WRB'), ('did', 'VBD'), ('Netflix', 'RB'), ('have', 'VB'), ('to', 'TO'), ('add', 'VB'), ('the', 'DT'), ('cursing', 'VBG'), ('The', 'DT'), ('show', 'NN'), ('was', 'VBD'), ('fine', 'JJ'), ('without', 'IN'), ('it', 'PRP'), ('Language', 'NNP'), ('doesn', 'VBZ'), ('t', 'JJ'), ('add', 'VB'), ('anything', 'NN'), ('to', 'TO'), ('the', 'DT'), ('quality', 'NN'), ('of', 'IN'), ('the', 'DT'), ('show', 'NN'), ('I', 'PRP'), ('know', 'VBP'), ('everyone', 'NN'), ('thinks', 'VBZ'), ('it', 'PRP'), ('makes', 'VBZ'), ('it', 'PRP'), ('more', 'RBR'), ('realistic', 'JJ'), ('but', 'CC'), ('I', 'PRP'), ('disagree', 'VBP'), ('It', 'PRP'), ('just', 'RB'), ('isn', 'VB'), ('t', 'NN'), ('needed', 'VBN')]
#
# Total No of Nouns: 9
# Total No of Verbs: 21
# Total No of Adjectives: 5
# Total No of Adverbs: 4
# POS tagging for row 995:
# [('This', 'DT'), ('show', 'NN'), ('is', 'VBZ'), ('one', 'CD'), ('of', 'IN'), ('my', 'PRP$'), ('favourite', 'JJ'), ('Netflix', 'NNP'), ('Originals', 'NNP'), ('It', 'PRP'), ('kind', 'NN'), ('of', 'IN'), ('combines', 'NNS'), ('House', 'NNP'), ('of', 'IN'), ('Cards', 'NNP'), ('2013', 'CD'), ('with', 'IN'), ('24', 'CD'), ('2001', 'CD'), ('really', 'RB'), ('well', 'RB'), ('with', 'IN'), ('it', 'PRP'), ('being', 'VBG'), ('half', 'JJ'), ('political', 'JJ'), ('drama', 'NN'), ('and', 'CC'), ('half', 'JJ'), ('action', 'NN'), ('thriller', 'IN'), ('All', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('main', 'JJ'), ('cast', 'NN'), ('play', 'NN'), ('such', 'JJ'), ('amazing', 'JJ'), ('likeable', 'JJ'), ('but', 'CC'), ('flawed', 'VBD'), ('characters', 'NNS'), ('Season', 'NNP'), ('One', 'CD'), ('is', 'VBZ'), ('by', 'IN'), ('far', 'RB'), ('the', 'DT'), ('best', 'JJS'), ('because', 'IN'), ('you', 'PRP'), ('just', 'RB'), ('had', 'VBD'), ('no', 'DT'), ('idea', 'NN'), ('where', 'WRB'), ('it', 'PRP'), ('was', 'VBD'), ('going', 'VBG'), ('season', 'NN'), ('two', 'CD'), ('kept', 'VBD'), ('the', 'DT'), ('suspense', 'NN'), ('with', 'IN'), ('a', 'DT'), ('different', 'JJ'), ('story', 'NN'), ('every', 'DT'), ('week', 'NN'), ('but', 'CC'), ('still', 'RB'), ('had', 'VBD'), ('long', 'JJ'), ('running', 'NN'), ('stories', 'NNS'), ('Season', 'NNP'), ('three', 'CD'), ('however', 'RB'), ('wasn', 'VBP'), ('t', 'NNS'), ('that', 'WDT'), ('good', 'VBD'), ('It', 'PRP'), ('had', 'VBD'), ('some', 'DT'), ('good', 'JJ'), ('moments', 'NNS'), ('but', 'CC'), ('it', 'PRP'), ('just', 'RB'), ('felt', 'VBD'), ('like', 'IN'), ('a', 'DT'), ('very', 'RB'), ('different', 'JJ'), ('show', 'NN')]
#
# Total No of Nouns: 25
# Total No of Verbs: 13
# Total No of Adjectives: 13
# Total No of Adverbs: 8
# POS tagging for row 996:
# [('Started', 'VBN'), ('off', 'RP'), ('brilliant', 'NN'), ('season', 'NN'), ('one', 'CD'), ('is', 'VBZ'), ('fantastic', 'JJ'), ('Season', 'NNP'), ('2', 'CD'), ('is', 'VBZ'), ('just', 'RB'), ('as', 'RB'), ('good', 'JJ'), ('But', 'CC'), ('the', 'DT'), ('whole', 'JJ'), ('tone', 'NN'), ('of', 'IN'), ('the', 'DT'), ('show', 'NN'), ('changes', 'VBZ'), ('in', 'IN'), ('season', 'NN'), ('3', 'CD'), ('ruined', 'VBD'), ('it', 'PRP'), ('for', 'IN'), ('me', 'PRP'), ('As', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('only', 'RB'), ('ten', 'JJ'), ('episodes', 'NNS'), ('I', 'PRP'), ('stuck', 'VBP'), ('with', 'IN'), ('it', 'PRP'), ('it', 'PRP'), ('just', 'RB'), ('got', 'VBD'), ('worse', 'JJR'), ('It', 'PRP'), ('was', 'VBD'), ('like', 'IN'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('characters', 'NNS'), ('personalities', 'NNS'), ('completely', 'RB'), ('changed', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('third', 'JJ'), ('season', 'NN'), ('What', 'WP'), ('s', 'VBZ'), ('great', 'JJ'), ('about', 'IN'), ('seasons', 'NNS'), ('one', 'CD'), ('and', 'CC'), ('two', 'CD'), ('is', 'VBZ'), ('it', 'PRP'), ('s', 'RB'), ('just', 'RB'), ('as', 'IN'), ('it', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('if', 'IN'), ('Jack', 'NNP'), ('Bauer', 'NNP'), ('ever', 'RB'), ('became', 'VBD'), ('president', 'NN'), ('loved', 'VBD'), ('that', 'IN'), ('The', 'DT'), ('acting', 'NN'), ('is', 'VBZ'), ('great', 'JJ'), ('in', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('two', 'CD'), ('seasons', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('storylines', 'NNS'), ('are', 'VBP'), ('great', 'JJ'), ('quickest', 'JJS'), ('I', 'PRP'), ('ve', 'VBP'), ('ever', 'RB'), ('got', 'VBN'), ('through', 'IN'), ('so', 'RB'), ('many', 'JJ'), ('episodes', 'NNS'), ('of', 'IN'), ('any', 'DT'), ('show', 'NN'), ('So', 'RB'), ('to', 'TO'), ('sum', 'VB'), ('up', 'RP'), ('definitely', 'RB'), ('worth', 'IN'), ('a', 'DT'), ('watch', 'NN'), ('but', 'CC'), ('probably', 'RB'), ('best', 'JJS'), ('to', 'TO'), ('forget', 'VB'), ('they', 'PRP'), ('ever', 'RB'), ('made', 'VBD'), ('a', 'DT'), ('third', 'JJ'), ('season', 'NN')]
#
# Total No of Nouns: 21
# Total No of Verbs: 22
# Total No of Adjectives: 14
# Total No of Adverbs: 14
# POS tagging for row 997:
# [('This', 'DT'), ('show', 'NN'), ('which', 'WDT'), ('I', 'PRP'), ('stumbled', 'VBD'), ('upon', 'RP'), ('when', 'WRB'), ('trying', 'VBG'), ('to', 'TO'), ('find', 'VB'), ('something', 'NN'), ('to', 'TO'), ('watch', 'VB'), ('grabbed', 'FW'), ('me', 'PRP'), ('right', 'VBD'), ('off', 'RP'), ('the', 'DT'), ('cuff', 'NN'), ('Full', 'NNP'), ('of', 'IN'), ('twists', 'NNS'), ('and', 'CC'), ('turns', 'VBZ'), ('incredible', 'JJ'), ('storylines', 'NNS'), ('and', 'CC'), ('great', 'JJ'), ('actors', 'NNS'), ('I', 'PRP'), ('am', 'VBP'), ('sold', 'VBN'), ('From', 'IN'), ('terrorists', 'NNS'), ('to', 'TO'), ('conspiracies', 'NNS'), ('to', 'TO'), ('family', 'NN'), ('and', 'CC'), ('finally', 'RB'), ('the', 'DT'), ('incredible', 'JJ'), ('conflicts', 'NNS'), ('going', 'VBG'), ('on', 'IN'), ('within', 'IN'), ('the', 'DT'), ('country', 'NN'), ('Watch', 'VBD'), ('it', 'PRP'), ('Now', 'RB')]
#
# Total No of Nouns: 12
# Total No of Verbs: 10
# Total No of Adjectives: 3
# Total No of Adverbs: 2
# POS tagging for row 998:
# [('I', 'PRP'), ('ve', 'VBP'), ('just', 'RB'), ('binge', 'NN'), ('watched', 'VBD'), ('it', 'PRP'), ('up', 'RP'), ('to', 'TO'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('Episode', 'NNP'), ('18', 'CD'), ('The', 'DT'), ('initial', 'JJ'), ('premise', 'NN'), ('is', 'VBZ'), ('interesting', 'VBG'), ('whether', 'IN'), ('or', 'CC'), ('not', 'RB'), ('it', 'PRP'), ('s', 'VBZ'), ('actually', 'RB'), ('based', 'VBN'), ('in', 'IN'), ('reality', 'NN'), ('You', 'PRP'), ('always', 'RB'), ('need', 'VBP'), ('to', 'TO'), ('grant', 'VB'), ('some', 'DT'), ('leeway', 'NN'), ('with', 'IN'), ('initial', 'JJ'), ('premises', 'NNS'), ('especially', 'RB'), ('these', 'DT'), ('days', 'NNS'), ('I', 'PRP'), ('stopped', 'VBD'), ('watching', 'VBG'), ('24', 'CD'), ('after', 'IN'), ('the', 'DT'), ('second', 'JJ'), ('season', 'NN'), ('because', 'IN'), ('I', 'PRP'), ('found', 'VBD'), ('it', 'PRP'), ('too', 'RB'), ('infantile', 'JJ'), ('and', 'CC'), ('silly', 'JJ'), ('I', 'PRP'), ('did', 'VBD'), ('watch', 'VB'), ('The', 'DT'), ('West', 'NNP'), ('Wing', 'NNP'), ('through', 'IN'), ('to', 'TO'), ('the', 'DT'), ('end', 'NN'), ('This', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('sort', 'NN'), ('of', 'IN'), ('24', 'CD'), ('meets', 'NNS'), ('The', 'DT'), ('West', 'NNP'), ('Wing', 'VBG'), ('The', 'DT'), ('show', 'NN'), ('lets', 'VBZ'), ('itself', 'PRP'), ('down', 'RP'), ('with', 'IN'), ('too', 'RB'), ('many', 'JJ'), ('loving', 'VBG'), ('gazes', 'NNS'), ('between', 'IN'), ('the', 'DT'), ('President', 'NNP'), ('and', 'CC'), ('his', 'PRP$'), ('wife', 'NN'), ('does', 'VBZ'), ('she', 'PRP'), ('have', 'VB'), ('any', 'DT'), ('flaws', 'NNS'), ('at', 'IN'), ('all', 'DT'), ('some', 'DT'), ('terribly', 'RB'), ('clunky', 'JJ'), ('lines', 'NNS'), ('and', 'CC'), ('worst', 'JJS'), ('of', 'IN'), ('all', 'PDT'), ('the', 'DT'), ('relentless', 'NN'), ('US', 'NNP'), ('Patriot', 'NNP'), ('buzz', 'NN'), ('word', 'NN'), ('laden', 'NN'), ('speeches', 'VBZ'), ('The', 'DT'), ('American', 'JJ'), ('people', 'NNS'), ('deserve', 'VBP'), ('Rebuilding', 'VBG'), ('our', 'PRP$'), ('amazing', 'JJ'), ('nation', 'NN'), ('Rebuilding', 'VBG'), ('our', 'PRP$'), ('fantastic', 'JJ'), ('Government', 'NNP'), ('There', 'EX'), ('s', 'VBZ'), ('no', 'DT'), ('mention', 'NN'), ('of', 'IN'), ('lobbyists', 'NNS'), ('or', 'CC'), ('Corporate', 'NNP'), ('involvement', 'NN'), ('in', 'IN'), ('Government', 'NNP'), ('There', 'EX'), ('s', 'VBZ'), ('no', 'DT'), ('mention', 'NN'), ('of', 'IN'), ('the', 'DT'), ('profound', 'NN'), ('disconnect', 'NN'), ('between', 'IN'), ('citizen', 'NN'), ('and', 'CC'), ('Government', 'NNP'), ('that', 'WDT'), ('is', 'VBZ'), ('a', 'DT'), ('feature', 'NN'), ('of', 'IN'), ('contemporary', 'JJ'), ('politics', 'NNS'), ('The', 'DT'), ('various', 'JJ'), ('third', 'JJ'), ('rails', 'NNS'), ('of', 'IN'), ('US', 'NNP'), ('politics', 'NNS'), ('are', 'VBP'), ('briefly', 'NN'), ('mentioned', 'VBD'), ('It', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('show', 'NN'), ('about', 'IN'), ('a', 'DT'), ('fantasy', 'NN'), ('America', 'NNP'), ('and', 'CC'), ('a', 'DT'), ('fantasy', 'JJ'), ('American', 'JJ'), ('Government', 'NNP'), ('It', 'PRP'), ('s', 'VBD'), ('the', 'DT'), ('TV', 'NN'), ('Show', 'NNP'), ('version', 'NN'), ('of', 'IN'), ('America', 'NNP'), ('that', 'WDT'), ('is', 'VBZ'), ('challenged', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('initial', 'JJ'), ('events', 'NNS'), ('and', 'CC'), ('it', 'PRP'), ('responds', 'VBZ'), ('the', 'DT'), ('way', 'NN'), ('TV', 'NN'), ('Show', 'NNP'), ('script', 'VBZ'), ('writers', 'NNS'), ('think', 'VBP'), ('such', 'PDT'), ('a', 'DT'), ('world', 'NN'), ('would', 'MD'), ('respond', 'VB'), ('Having', 'NNP'), ('said', 'VBD'), ('all', 'DT'), ('that', 'IN'), ('it', 'PRP'), ('moves', 'VBZ'), ('reasonably', 'RB'), ('quickly', 'RB'), ('and', 'CC'), ('the', 'DT'), ('split', 'NN'), ('between', 'IN'), ('the', 'DT'), ('two', 'CD'), ('story', 'NN'), ('arcs', 'NN'), ('is', 'VBZ'), ('well', 'RB'), ('handled', 'VBN'), ('and', 'CC'), ('engaging', 'VBG'), ('The', 'DT'), ('only', 'JJ'), ('caveat', 'NN'), ('is', 'VBZ'), (' ...
#
# Total No of Nouns: 73
# Total No of Verbs: 50
# Total No of Adjectives: 24
# Total No of Adverbs: 15
# POS tagging for row 999:
# [('I', 'PRP'), ('wish', 'VBP'), ('Tom', 'NNP'), ('Kirkman', 'NNP'), ('were', 'VBD'), ('our', 'PRP$'), ('actual', 'JJ'), ('president', 'NN'), ('Great', 'NNP'), ('characters', 'NNS'), ('and', 'CC'), ('keeps', 'VBZ'), ('you', 'PRP'), ('going', 'VBG')]
#
# Total No of Nouns: 5
# Total No of Verbs: 4
# Total No of Adjectives: 1
# Total No of Adverbs: 0
# POS tagging for row 1000:
# [('Nothing', 'NN'), ('is', 'VBZ'), ('added', 'VBN'), ('by', 'IN'), ('Netflix', 'NNP'), ('s', 'JJ'), ('inclusion', 'NN'), ('of', 'IN'), ('profanity', 'NN'), ('for', 'IN'), ('this', 'DT'), ('new', 'JJ'), ('season', 'NN'), ('Just', 'NNP'), ('because', 'IN'), ('you', 'PRP'), ('Can', 'MD'), ('doesn', 'VB'), ('t', 'JJ'), ('mean', 'NN'), ('you', 'PRP'), ('Should', 'VBP'), ('A', 'DT'), ('famous', 'JJ'), ('adage', 'NN'), ('that', 'WDT'), ('applies', 'VBZ'), ('especially', 'RB'), ('when', 'WRB'), ('it', 'PRP'), ('affects', 'VBZ'), ('the', 'DT'), ('tenor', 'NN'), ('and', 'CC'), ('tone', 'NN'), ('of', 'IN'), ('a', 'DT'), ('show', 'NN'), ('that', 'WDT'), ('survived', 'VBD'), ('without', 'IN'), ('It', 'PRP'), ('is', 'VBZ'), ('actually', 'RB'), ('distracting', 'JJ'), ('and', 'CC'), ('takes', 'VBZ'), ('away', 'RB'), ('from', 'IN'), ('the', 'DT'), ('enjoyment', 'NN'), ('of', 'IN'), ('the', 'DT'), ('show', 'NN')]
#
# Total No of Nouns: 13
# Total No of Verbs: 9
# Total No of Adjectives: 5
# Total No of Adverbs: 3
# POS tagging for row 1001:
# [('The', 'DT'), ('pilot', 'NN'), ('episode', 'NN'), ('was', 'VBD'), ('intriguing', 'VBG'), ('but', 'CC'), ('as', 'IN'), ('Designated', 'NNP'), ('Survivor', 'NNP'), ('just', 'RB'), ('watched', 'VBD'), ('episode', 'RB'), ('5', 'CD'), ('goes', 'VBZ'), ('on', 'IN'), ('it', 'PRP'), ('s', 'VBZ'), ('really', 'RB'), ('hitting', 'VBG'), ('it', 'PRP'), ('s', 'JJ'), ('stride', 'JJ'), ('Kiefer', 'NNP'), ('s', 'NN'), ('acting', 'NN'), ('is', 'VBZ'), ('compelling', 'VBG'), ('and', 'CC'), ('all', 'DT'), ('of', 'IN'), ('the', 'DT'), ('characters', 'NNS'), ('are', 'VBP'), ('beginning', 'VBG'), ('to', 'TO'), ('get', 'VB'), ('fleshed', 'VBN'), ('out', 'RP'), ('as', 'IN'), ('the', 'DT'), ('story', 'NN'), ('begins', 'VBZ'), ('to', 'TO'), ('come', 'VB'), ('together', 'RB'), ('The', 'DT'), ('idea', 'NN'), ('of', 'IN'), ('an', 'DT'), ('every', 'DT'), ('man', 'NN'), ('becoming', 'VBG'), ('President', 'NNP'), ('is', 'VBZ'), ('interesting', 'JJ'), ('as', 'IN'), ('he', 'PRP'), ('copes', 'VBZ'), ('with', 'IN'), ('the', 'DT'), ('difficult', 'JJ'), ('choices', 'NNS'), ('he', 'PRP'), ('has', 'VBZ'), ('to', 'TO'), ('make', 'VB'), ('and', 'CC'), ('the', 'DT'), ('effects', 'NNS'), ('his', 'PRP$'), ('new', 'JJ'), ('job', 'NN'), ('have', 'VBP'), ('on', 'IN'), ('him', 'PRP'), ('and', 'CC'), ('his', 'PRP$'), ('family', 'NN'), ('Actually', 'RB'), ('showing', 'VBG'), ('the', 'DT'), ('incredible', 'JJ'), ('toll', 'NN'), ('that', 'IN'), ('making', 'VBG'), ('life', 'NN'), ('and', 'CC'), ('death', 'NN'), ('decisions', 'NNS'), ('a', 'DT'), ('decent', 'JJ'), ('man', 'NN'), ('who', 'WP'), ('is', 'VBZ'), ('president', 'NN'), ('has', 'VBZ'), ('to', 'TO'), ('make', 'VB'), ('is', 'VBZ'), ('so', 'RB'), ('enlightening', 'JJ'), ('and', 'CC'), ('Kiefer', 'NNP'), ('is', 'VBZ'), ('masterful', 'JJ'), ('at', 'IN'), ('portraying', 'VBG'), ('the', 'DT'), ('pathos', 'NN'), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('the', 'DT'), ('joy', 'NN'), ('Adding', 'VBG'), ('the', 'DT'), ('conspiracy', 'NN'), ('suspense', 'NN'), ('to', 'TO'), ('the', 'DT'), ('mix', 'NN'), ('makes', 'VBZ'), ('it', 'PRP'), ('edge', 'NN'), ('of', 'IN'), ('your', 'PRP$'), ('seat', 'NN'), ('viewing', 'VBG'), ('This', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('first', 'JJ'), ('new', 'JJ'), ('show', 'NN'), ('in', 'IN'), ('a', 'DT'), ('long', 'JJ'), ('time', 'NN'), ('that', 'IN'), ('I', 'PRP'), ('actually', 'RB'), ('look', 'VBP'), ('forward', 'RB'), ('to', 'TO'), ('watching', 'VBG')]
#
# Total No of Nouns: 32
# Total No of Verbs: 34
# Total No of Adjectives: 12
# Total No of Adverbs: 10

# %%
# !pip install benepar
# !pip install benepar nltk
# !pip install tensorflow
# !pip install tensorflow==2.8.0
# Out:
# Collecting benepar
#   Downloading benepar-0.2.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.2 in /usr/local/lib/python3.11/dist-packages (from benepar) (3.9.1)
# Requirement already satisfied: spacy>=2.0.9 in /usr/local/lib/python3.11/dist-packages (from benepar) (3.7.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from benepar) (2.5.1+cu124)
# Collecting torch-struct>=0.5 (from benepar)
#   Downloading torch_struct-0.5-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tokenizers>=0.9.4 in /usr/local/lib/python3.11/dist-packages (from benepar) (0.21.0)
# Requirement already satisfied: transformers>=4.2.2 in /usr/local/lib/python3.11/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (4.48.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from benepar) (4.25.6)
# Requirement already satisfied: sentencepiece>=0.1.91 in /usr/local/lib/python3.11/dist-packages (from benepar) (0.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2->benepar) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2->benepar) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2->benepar) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2->benepar) (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (0.15.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.26.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.9.4->benepar) (0.28.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.6.0->benepar)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.6.0->benepar)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.6.0->benepar)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.6.0->benepar)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.6.0->benepar)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.6.0->benepar)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.6.0->benepar)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.6.0->benepar)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.6.0->benepar)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.6.0->benepar)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6.0->benepar) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.2.2->transformers[tokenizers,torch]>=4.2.2->benepar) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.2.2->transformers[tokenizers,torch]>=4.2.2->benepar) (0.5.2)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.26.0->transformers[tokenizers,torch]>=4.2.2->benepar) (5.9.5)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=2.0.9->benepar) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.9->benepar) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.9->benepar) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.9->benepar) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.9->benepar) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy>=2.0.9->benepar) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=2.0.9->benepar) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (0.1.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.9 MB/s eta 0:00:00
# Downloading torch_struct-0.5-py3-none-any.whl (34 kB)
# Building wheels for collected packages: benepar
#   Building wheel for benepar (setup.py) ... done
#   Created wheel for benepar: filename=benepar-0.2.0-py3-none-any.whl size=37626 sha256=5667d3e984dd98e73585b9e8fd9c68fee5e1603b193d72fbfc6a32a85d222915
#   Stored in directory: /root/.cache/pip/wheels/a7/06/97/846995c0825bbc92825ce41675b6d5477213b25e167115223f
# Successfully built benepar
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch-struct, benepar
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed benepar-0.2.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torch-struct-0.5
# Requirement already satisfied: benepar in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: spacy>=2.0.9 in /usr/local/lib/python3.11/dist-packages (from benepar) (3.7.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from benepar) (2.5.1+cu124)
# Requirement already satisfied: torch-struct>=0.5 in /usr/local/lib/python3.11/dist-packages (from benepar) (0.5)
# Requirement already satisfied: tokenizers>=0.9.4 in /usr/local/lib/python3.11/dist-packages (from benepar) (0.21.0)
# Requirement already satisfied: transformers>=4.2.2 in /usr/local/lib/python3.11/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (4.48.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from benepar) (4.25.6)
# Requirement already satisfied: sentencepiece>=0.1.91 in /usr/local/lib/python3.11/dist-packages (from benepar) (0.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (0.15.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (2.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=2.0.9->benepar) (1.26.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.9.4->benepar) (0.28.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.6.0->benepar) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.6.0->benepar) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.2.2->transformers[tokenizers,torch]>=4.2.2->benepar) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.2.2->transformers[tokenizers,torch]>=4.2.2->benepar) (0.5.2)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.26.0->transformers[tokenizers,torch]>=4.2.2->benepar) (5.9.5)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=2.0.9->benepar) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.9->benepar) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.9->benepar) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.9->benepar) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy>=2.0.9->benepar) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy>=2.0.9->benepar) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=2.0.9->benepar) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=2.0.9->benepar) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.0.9->benepar) (0.1.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.8.0 (from versions: 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0)
# ERROR: No matching distribution found for tensorflow==2.8.0

# %%
#Part2:Constituency Parsing and Dependency Parsing:
# Importing the libraries
import benepar
import sys
import spacy
from spacy import displacy
benepar.download('benepar_en3')
parser = benepar.Parser("benepar_en3")
nlp = spacy.load('en_core_web_sm')
options = {'compact': True, 'font': 'Arial black', 'distance': 100}
# Parsing a sentence in clean_text
try:
    tree = parser.parse(df['clean_text'][2])
    print(tree)
except:
    print("No Parse Tree")

doc = nlp(df['clean_text'][2])
displacy.render(doc, style='dep', options=options, jupyter=True)
# Out:
# [nltk_data] Downloading package benepar_en3 to /root/nltk_data...
# [nltk_data]   Unzipping models/benepar_en3.zip.
# /usr/local/lib/python3.11/dist-packages/benepar/parse_chart.py:169: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# (TOP
#   (S
#     (NP
#       (NP (NN Season) (CD One) (CC and) (CD Two))
#       (VBD were)
#       (ADJP (JJ fantastic))
#       (JJ Interesting)
#       (VBG gripping)
#       (JJ great)
#       (NN cast)
#       (CC and)
#       (NN production))
#     (NP (PRP I))
#     (VP
#       (VP
#         (MD couldn)
#         (RB t)
#         (VP
#           (VB wait)
#           (PP
#             (IN for)
#             (NP
#               (NP (DT the) (JJ next) (NN episode))
#               (SBAR
#                 (IN After)
#                 (S
#                   (NP (NNP Netflix))
#                   (VP
#                     (VBD took)
#                     (PRT (RP over))
#                     (NP (NNP Season) (NNP Three)))))))))
#       (NP (PRP I))
#       (VP
#         (VBD stopped)
#         (VBG watching)
#         (SBAR
#           (IN after)
#           (S
#             (NP
#               (NP
#                 (NP
#                   (NP (QP (RB about) (CD one) (NN third)))
#                   (PP (IN of) (NP (DT the) (NNS episodes))))
#                 (SBAR
#                   (S
#                     (NP (NNP Season) (NNP Three))
#                     (VP
#                       (VBZ is)
#                       (VP
#                         (VP (VBN obsessed))
#                         (CC and)
#                         (VP
#                           (VBN strategized)
#                           (PP
#                             (IN with)
#                             (NP
#                               (NP
#                                 (NP
#                                   (JJ misguided)
#                                   (NN identity)
#                                   (NNS politics))
#                                 (NP
#                                   (ADJP
#                                     (RB politically)
#                                     (JJ correct))
#                                   (NN content)))
#                               (CC and)
#                               (NP (JJ crass) (NN language))))))))))
#               (NP
#                 (NP (DT The) (NNS screenplays))
#                 (PP (IN for) (NP (NNP Season) (NNP Three)))))
#             (VP
#               (VP (VBP are) (ADJP (JJ amateurish)))
#               (CC and)
#               (VP
#                 (ADVP (RB nowhere))
#                 (VP
#                   (VB match)
#                   (NP
#                     (NP (DT those))
#                     (PP
#                       (IN of)
#                       (NP
#                         (NP (NNP Season) (CD One) (CC and) (CD Two))
#                         (NNP Strange))))
#                   (SBAR
#                     (WHADVP (WRB when))
#                     (S
#                       (NP (NNP Netflix))
#                       (VP
#                         (VBZ produces)
#                         (NP
#                           (NP (NNS things))
#                           (VP (VB get) (ADJP (JJ sleazy))))))))))))))))
# /usr/local/lib/python3.11/dist-packages/torch/distributions/distribution.py:56: UserWarning: <class 'torch_struct.distributions.TreeCRF'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="437590286fee4d36869306fb7b95c079-0" class="displacy" width="8950" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial black; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Season</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">One</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">were</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">fantastic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Interesting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">gripping</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">great</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">cast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">production</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">couldn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">t</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">wait</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">next</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">episode</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2550">After</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">Netflix</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">took</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="2950">Season</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Three</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="30

# %% [markdown]
# # **Following Questions must answer using AI assitance**

# %% [markdown]
# #Question 4 (20 points).

# %% [markdown]
# Q4. (PART-1)
# Web scraping data from the GitHub Marketplace to gather details about popular actions. Using Python, the process begins by sending HTTP requests to multiple pages of the marketplace (1000 products), handling pagination through dynamic page numbers. The key details extracted include the product name, a short description, and the URL.
#
#  The extracted data is stored in a structured CSV format with columns for product name, description, URL, and page number. A time delay is introduced between requests to avoid server overload. ChatGPT can assist by helping with the parsing of HTML, error handling, and generating reports based on the data collected.
#
#  The goal is to complete the scraping within a specified time limit, ensuring that the process is efficient and adheres to GitHub’s usage guidelines.
#
# (PART -2)
#
# 1.   **Preprocess Data**: Clean the text by tokenizing, removing stopwords, and converting to lowercase.
#
# 2. Perform **Data Quality** operations.
#
#
# Preprocessing:
# Preprocessing involves cleaning the text by removing noise such as special characters, HTML tags, and unnecessary whitespace. It also includes tasks like tokenization, stopword removal, and lemmatization to standardize the text for analysis.
#
# Data Quality:
# Data quality checks ensure completeness, consistency, and accuracy by verifying that all required columns are filled and formatted correctly. Additionally, it involves identifying and removing duplicates, handling missing values, and ensuring the data reflects the true content accurately.

# %%
#Part 1
import time

# Base URL of GitHub Marketplace (Actions section)
BASE_URL = "https://github.com/marketplace?type=actions&page="

# Headers to mimic a browser request
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Referer": "https://www.google.com/",
}

# Initialize list to store data
data = []
page = 0
# Scrape multiple pages (Assuming 40 products per page, we need ~25 pages for 1000 products)
while len(data)<1000:
    page+=1
    url = f"{BASE_URL}{page}"

    response = requests.get(url, headers=headers)
    #print(response.text)
    if response.status_code != 200:
        print(f"Failed to fetch page {page}")
        continue

    soup = BeautifulSoup(response.text, "html.parser")

    # Find all product containers

    items = soup.find_all('div', {'data-testid': 'non-featured-item'})
    for item in items:
        try:
            name = item.find('a', class_='marketplace-common-module__marketplace-item-link--jrIHf').text.strip()
            url = "https://github.com" + item.find('a')['href']
            description = item.find('p', class_='text-small').text.strip()
            data.append([name, description, url, page])
        except AttributeError:
            continue

# Save to CSV
df = pd.DataFrame(data, columns=["Product Name", "Description", "URL", "Page Number"])

df.to_csv("github_marketplace_actions.csv", index=False)
print("Scraping completed! Data saved to github_marketplace_actions.csv")
# Out:
# Scraping completed! Data saved to github_marketplace_actions.csv

# %% [markdown]
# Github MarketPlace page:
# https://github.com/marketplace?type=actions

# %%
#Part2
from nltk.tokenize import word_tokenize
df = pd.read_csv('/content/github_marketplace_actions.csv')

# Data Cleaning Function
def clean_text(text):
    text = str(text)  # Ensure it's a string
    text = re.sub(r"<.*?>", "", text)  # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)  # Remove special characters
    text = text.lower()  # Convert to lowercase
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    return text

# Apply text cleaning to Name & Description columns
df["Product Name"] = df["Product Name"].apply(clean_text)
df["Description"] = df["Description"].apply(clean_text)

# Tokenization, Stopword Removal, Lemmatization
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]  # Remove stopwords
    tokens = [lemmatizer.lemmatize(word) for word in tokens]  # Lemmatization
    return " ".join(tokens)

df["Processed Description"] = df["Description"].apply(preprocess_text)

# Data Quality Checks
df.drop_duplicates(inplace=True)  # Remove duplicates
df.dropna(inplace=True)  # Handle missing values

# Save cleaned data
df.to_csv("cleaned_github_marketplace_actions.csv", index=False)

print("Data preprocessing and quality checks completed. Cleaned data saved.")
# Out:
# Data preprocessing and quality checks completed. Cleaned data saved.

# %% [markdown]
# #Question 5 (20 points)
#
# PART 1:
# Web Scrape  tweets from Twitter using the Tweepy API, specifically targeting hashtags related to subtopics (machine learning or artificial intelligence.)
# The extracted data includes the tweet ID, username, and text.
#
# Part 2:
# Perform data cleaning procedures
#
# A final data quality check ensures the completeness and consistency of the dataset. The cleaned data is then saved into a CSV file for further analysis.
#
#
# **Note**
#
# 1.   Follow tutorials provided in canvas to obtain api keys. Use ChatGPT to get the code. Make sure the file is downloaded and saved.
# 2.   Make sure you divide GPT code as shown in tutorials, dont make multiple requestes.

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.11/dist-packages (4.15.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (2.32.3)
# Requirement already satisfied: requests-oauthlib<3,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from tweepy) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27.0->tweepy) (2025.1.31)

# %%
import tweepy

# Set your keys and tokens here
api_key = ''
api_key_secret = ''
access_token = ''
access_token_secret =''
# Authenticate with Twitter
auth = tweepy.OAuth1UserHandler(
    consumer_key=api_key,
    consumer_secret=api_key_secret,
    access_token=access_token,
    access_token_secret=access_token_secret
)
api = tweepy.API(auth)

# %%
import tweepy
import pandas as pd
import re
import ssl
import time

# Fix SSL issue
ssl._create_default_https_context = ssl._create_unverified_context

# Step 1: Set up Twitter API authentication
API_KEY = "q3ENmou7Z9BwGpatEbxAaP6Tt"
API_SECRET = "igiWK4qSdUVmBoIPhCNc7i7Y19293720zwclgAXVLr7TmwLTfX"
ACCESS_TOKEN = "1892384049131638785-ZSsF3IvEHK2pfniPvdAxFlg1Nj2SCR"
ACCESS_SECRET = "S4sOXZq9aBlzhMyTOUEgzv1SOVfVCSH0bpzOeaUgLGL1a"

# Authenticate with Twitter API using OAuth 2.0
auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True)

# Step 2: Scrape tweets based on hashtags
def scrape_tweets(hashtag, count=100):
    tweets = []
    try:
        for tweet in tweepy.Cursor(api.search_tweets, q=hashtag, lang="en", tweet_mode="extended").items(count):
            tweets.append([tweet.id_str, tweet.user.screen_name, tweet.full_text])
        time.sleep(2)  # Prevent hitting rate limits
    except tweepy.TooManyRequests:
        print("Rate limit exceeded. Waiting for 15 minutes...")
        time.sleep(900)  # Wait for 15 minutes before retrying
    except Exception as e:
        print(f"Error: {e}")
    return tweets

# Define hashtags
hashtags = ["#MachineLearning", "#ArtificialIntelligence"]

data = []
for tag in hashtags:
    data.extend(scrape_tweets(tag, count=100))

# Convert to DataFrame
df = pd.DataFrame(data, columns=["Tweet_ID", "Username", "Text"])

# Step 3: Data Cleaning
def clean_text(text):
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'@[A-Za-z0-9_]+', '', text)  # Remove mentions
    text = re.sub(r'#[A-Za-z0-9_]+', '', text)  # Remove hashtags
    text = re.sub(r'[^A-Za-z0-9 ]+', '', text)  # Remove special characters
    text = text.lower().strip()  # Convert to lowercase and trim spaces
    return text

df["Cleaned_Text"] = df["Text"].apply(clean_text)

# Step 4: Final Data Quality Check
print("Total rows before cleaning:", len(df))
df.drop_duplicates(subset="Cleaned_Text", inplace=True)  # Remove duplicates
print("Total rows after cleaning:", len(df))

# Step 5: Save cleaned data to CSV
df.to_csv("cleaned_tweets.csv", index=False)
print("Cleaned data saved successfully!")
# Out:
# Error: 403 Forbidden
# 453 - You currently have access to a subset of X API V2 endpoints and limited v1.1 endpoints (e.g. media post, oauth) only. If you need access to this endpoint, you may need a different access level. You can learn more here: https://developer.x.com/en/portal/product
# Error: 403 Forbidden
# 453 - You currently have access to a subset of X API V2 endpoints and limited v1.1 endpoints (e.g. media post, oauth) only. If you need access to this endpoint, you may need a different access level. You can learn more here: https://developer.x.com/en/portal/product
# Total rows before cleaning: 0
# Total rows after cleaning: 0
# Cleaned data saved successfully!

# %% [markdown]
# # Write your response below
# Fill out survey and provide your valuable feedback.
#
# https://docs.google.com/forms/d/e/1FAIpQLSd_ObuA3iNoL7Az_C-2NOfHodfKCfDzHZtGRfIker6WyZqTtA/viewform?usp=dialog
